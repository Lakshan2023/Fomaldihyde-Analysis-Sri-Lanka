# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
colomboProperData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/ColomboProperHandledNullValues.csv")
mataraDeniyayaData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/MataraDeniyayaHandledNullValues.csv")
nuwaraEliyaData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/NuwaraEliyaHandledNullValues.csv")
bibileMonaragalaData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/BibileMonaragalaHandledNullValues.csv")
kurunegalaData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/KurunegalaProperHandledNullValues.csv")
jaffnaData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/jaffnaHandledNullValues.csv")
kandyData = pd.read_csv("../FomaldihydeAnalysis/NullValueHandled/KandyHandledNullValues.csv")

# %% [markdown]
# ## Analyse Colombo Proper Data Statistics

# %%
colomboProperData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000197
# 1   2019-01-02  2019-01-03      0.000263
# 2   2019-01-03  2019-01-04      0.000099
# 3   2019-01-04  2019-01-05      0.000210
# 4   2019-01-05  2019-01-06      0.000179

# %%
colomboProperData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
colomboProperData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000151
# std        0.000086
# min       -0.000112
# 25%        0.000092
# 50%        0.000144
# 75%        0.000209
# max        0.000415

# %% [markdown]
# ## Analyse Matara Deniyaya Data Statistics

# %%
mataraDeniyayaData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000006
# 1   2019-01-02  2019-01-03      0.000006
# 2   2019-01-03  2019-01-04      0.000236
# 3   2019-01-04  2019-01-05      0.000064
# 4   2019-01-05  2019-01-06      0.000053

# %%
mataraDeniyayaData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
mataraDeniyayaData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000088
# std        0.000060
# min       -0.000123
# 25%        0.000054
# 50%        0.000083
# 75%        0.000120
# max        0.000320

# %% [markdown]
# ## Analyse NuwaraEliya Data Statistics

# %%
nuwaraEliyaData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000191
# 1   2019-01-02  2019-01-03      0.000191
# 2   2019-01-03  2019-01-04      0.000191
# 3   2019-01-04  2019-01-05      0.000051
# 4   2019-01-05  2019-01-06      0.000065

# %%
nuwaraEliyaData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
nuwaraEliyaData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000083
# std        0.000054
# min       -0.000109
# 25%        0.000054
# 50%        0.000079
# 75%        0.000110
# max        0.000293

# %% [markdown]
# ## Analyse Bibile Monaragala Data Statistics

# %%
bibileMonaragalaData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000019
# 1   2019-01-02  2019-01-03      0.000019
# 2   2019-01-03  2019-01-04      0.000028
# 3   2019-01-04  2019-01-05      0.000037
# 4   2019-01-05  2019-01-06     -0.000018

# %%
bibileMonaragalaData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
bibileMonaragalaData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000120
# std        0.000073
# min       -0.000125
# 25%        0.000072
# 50%        0.000119
# 75%        0.000166
# max        0.000373

# %% [markdown]
# ## Analyse Kurunegala Data Statistics

# %%
kurunegalaData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000088
# 1   2019-01-02  2019-01-03      0.000137
# 2   2019-01-03  2019-01-04      0.000148
# 3   2019-01-04  2019-01-05     -0.000002
# 4   2019-01-05  2019-01-06      0.000249

# %%
kurunegalaData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
kurunegalaData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000127
# std        0.000067
# min       -0.000078
# 25%        0.000081
# 50%        0.000121
# 75%        0.000171
# max        0.000330

# %% [markdown]
# ## Analyse Jaffna Data Statistics

# %%
jaffnaData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000058
# 1   2019-01-02  2019-01-03      0.000102
# 2   2019-01-03  2019-01-04      0.000039
# 3   2019-01-04  2019-01-05     -0.000002
# 4   2019-01-05  2019-01-06      0.000159

# %%
jaffnaData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
jaffnaData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000105
# std        0.000060
# min       -0.000089
# 25%        0.000067
# 50%        0.000101
# 75%        0.000139
# max        0.000302

# %% [markdown]
# ## Analyse Kandy Data Statistics

# %%
kandyData.head()
# Out:
#   Current Date   Next Date  HCHO reading
# 0   2019-01-01  2019-01-02      0.000176
# 1   2019-01-02  2019-01-03      0.000092
# 2   2019-01-03  2019-01-04      0.000134
# 3   2019-01-04  2019-01-05      0.000191
# 4   2019-01-05  2019-01-06      0.000122

# %%
kandyData.isnull().sum()
# Out:
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
kandyData.describe()
# Out:
#        HCHO reading
# count   1826.000000
# mean       0.000101
# std        0.000068
# min       -0.000120
# 25%        0.000061
# 50%        0.000099
# 75%        0.000139
# max        0.000322

# %% [markdown]
# ## Combine All dataframes

# %%
# Creating the "Region" column based on each DataFrame

colomboProperData['Region'] = ["Colombo Proper" for x in range(0, len(colomboProperData))]
mataraDeniyayaData['Region'] = ["Deniyaya, Matara" for x in range(0, len(mataraDeniyayaData))]
nuwaraEliyaData['Region'] = ["Nuwara Eliya Proper" for x in range(0, len(nuwaraEliyaData))]
bibileMonaragalaData['Region'] = ["Bibile, Monaragala" for x in range(0, len(bibileMonaragalaData))]
kurunegalaData['Region'] = ["Kurunegala Proper" for x in range(0, len(kurunegalaData))]
jaffnaData['Region'] = ["Jaffna Proper" for x in range(0, len(jaffnaData))]
kandyData['Region'] = ["Kandy Proper" for x in range(0, len(kandyData))]

# %%
# Set the "Region" column as the index for each DataFrame
colomboProperData.set_index('Region', inplace=True)
mataraDeniyayaData.set_index('Region', inplace=True)
nuwaraEliyaData.set_index('Region', inplace=True)
bibileMonaragalaData.set_index('Region', inplace=True)
kurunegalaData.set_index('Region', inplace=True)
jaffnaData.set_index('Region', inplace=True)
kandyData.set_index('Region', inplace=True)

# Concatenate DataFrames along the index axis
joined_data = pd.concat([colomboProperData, mataraDeniyayaData, nuwaraEliyaData,
                         bibileMonaragalaData, kurunegalaData, jaffnaData, kandyData])

# Reset the index to make "Region" a column again
joined_data.reset_index(inplace=True)

# %%
data = joined_data

# %%
data.isnull().sum()
# Out:
# Region          0
# Current Date    0
# Next Date       0
# HCHO reading    0
# dtype: int64

# %%
data.head()
# Out:
#            Region Current Date   Next Date  HCHO reading
# 0  Colombo Proper   2019-01-01  2019-01-02      0.000197
# 1  Colombo Proper   2019-01-02  2019-01-03      0.000263
# 2  Colombo Proper   2019-01-03  2019-01-04      0.000099
# 3  Colombo Proper   2019-01-04  2019-01-05      0.000210
# 4  Colombo Proper   2019-01-05  2019-01-06      0.000179

# %% [markdown]
# ## Statistics of whole dataset

# %%
data.describe()
# Out:
#        HCHO reading
# count  12782.000000
# mean       0.000111
# std        0.000071
# min       -0.000125
# 25%        0.000066
# 50%        0.000103
# 75%        0.000152
# max        0.000415

# %%
data.set_index("Current Date", inplace=True)

# %%
data.head()
# Out:
#                       Region   Next Date  HCHO reading
# Current Date
# 2019-01-01    Colombo Proper  2019-01-02      0.000197
# 2019-01-02    Colombo Proper  2019-01-03      0.000263
# 2019-01-03    Colombo Proper  2019-01-04      0.000099
# 2019-01-04    Colombo Proper  2019-01-05      0.000210
# 2019-01-05    Colombo Proper  2019-01-06      0.000179

# %%
import pandas as pd
import plotly.graph_objects as go

# Assuming 'Next Date' column is not in datetime format
joined_data['Next Date'] = pd.to_datetime(joined_data['Next Date'])

# Filter data for the year 2019
joined_data_2019 = joined_data[joined_data['Next Date'].dt.year == 2019]

# Group data by region
grouped = joined_data_2019.groupby("Region")

# Create a Plotly figure
fig = go.Figure()

# Plot data for each region
for region, data in grouped:
    fig.add_trace(go.Scatter(x=data['Next Date'], y=data['HCHO reading'], mode='lines', name=region))

# Adding labels and title
fig.update_layout(title='HCHO Readings of All Regions Over the Year 2019',
                  xaxis_title='Date',
                  yaxis_title='HCHO Reading',
                  xaxis=dict(
                      rangeselector=dict(
                          buttons=list([
                              dict(count=1, label="1m", step="month", stepmode="backward"),
                              dict(count=6, label="6m", step="month", stepmode="backward"),
                              dict(count=1, label="1y", step="year", stepmode="backward"),
                              dict(step="all")
                          ])
                      ),
                      rangeslider=dict(visible=True),
                      type="date"
                  )
                  )

# Display the plot
fig.show()
# Out:
# <div>                            <div id="e449bf06-2333-4ce1-866e-fb917025f6bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e449bf06-2333-4ce1-866e-fb917025f6bd")) {                    Plotly.newPlot(                        "e449bf06-2333-4ce1-866e-fb917025f6bd",                        [{"mode":"lines","name":"Bibile, Monaragala","x":["2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00",
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'Next Date' column is not in datetime format
joined_data['Next Date'] = pd.to_datetime(joined_data['Next Date'])

# Filter data for the year 2019
joined_data_2019 = joined_data[joined_data['Next Date'].dt.year == 2019]

# Group data by region
grouped = joined_data_2019.groupby("Region")

# Initialize axis
ax = None

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data for each region
for region, data in grouped:
    ax.plot(data['Next Date'], data['HCHO reading'], label=region)

# Adding labels and title
ax.set_title('HCHO Readings of All Regions Over the Year 2019')
ax.set_xlabel('Date')
ax.set_ylabel('HCHO Reading')

# Adding legend
ax.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objs as go
import pandas as pd

# Assuming joined_data is your DataFrame with regions as columns and years as rows
# You may need to pivot your data or prepare it differently based on your DataFrame structure

# Create traces for each region
traces = []
for region in joined_data['Region'].unique():
    region_data = joined_data[joined_data['Region'] == region]
    trace = go.Scatter(x=region_data['Next Date'], y=region_data['HCHO reading'], mode='lines+markers', name=region)
    traces.append(trace)

# Create buttons for each region
buttons = []
for i, region in enumerate(joined_data['Region'].unique()):
    visible = [False] * len(joined_data['Region'].unique())
    visible[i] = True
    button = dict(label=region, method='update', args=[{'visible': visible}, {'title': f'HCHO Readings of {region} Over Years'}])
    buttons.append(button)

# Layout settings
layout = dict(title='HCHO Readings of All Regions Over Years', xaxis=dict(title='Year'), yaxis=dict(title='HCHO Reading'),
              updatemenus=[dict(buttons=buttons, direction='down', x=0.01, xanchor='left', y=1.15, yanchor='top')])

# Create figure
fig = go.Figure(data=traces, layout=layout)

# Display the plot
fig.show()
# Out:
# <div>                            <div id="c663dd9b-6d18-460b-844b-6e1c2b3cd7bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c663dd9b-6d18-460b-844b-6e1c2b3cd7bc")) {                    Plotly.newPlot(                        "c663dd9b-6d18-460b-844b-6e1c2b3cd7bc",                        [{"mode":"lines+markers","name":"Colombo Proper","x":["2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:
# ...
