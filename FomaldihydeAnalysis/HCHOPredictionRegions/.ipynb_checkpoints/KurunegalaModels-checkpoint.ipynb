# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, explained_variance_score

# %%
data = pd.read_csv("../NullValueHandled/KurunegalaProperHandledNullValues.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                Next Date  HCHO reading
# Current Date
# 2019-01-01    2019-01-02      0.000088
# 2019-01-02    2019-01-03      0.000137
# 2019-01-03    2019-01-04      0.000148
# 2019-01-04    2019-01-05     -0.000002
# 2019-01-05    2019-01-06      0.000249

# %%
kurunegala_data = data[["HCHO reading"]]
kurunegala_data.head()
# Out:
#               HCHO reading
# Current Date
# 2019-01-01        0.000088
# 2019-01-02        0.000137
# 2019-01-03        0.000148
# 2019-01-04       -0.000002
# 2019-01-05        0.000249

# %%
kurunegala_data.shape
# Out:
# (1826, 1)

# %%
X = kurunegala_data.values

# %% [markdown]
# #### This looks like that Kurunegala fomaldihyde rates have a seasonality

# %%
kurunegala_data.plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='Current Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_kurunegala = adfuller(kurunegala_data["HCHO reading"], autolag="AIC")

# %%
print("ADF value : ", test_kurunegala[0])
print("P value: ", test_kurunegala[1])
print("Num of Lags :", test_kurunegala[2])
print("Num of Observations used for ADF Regression and Critical Calculation :", test_kurunegala[3])
for key, val in test_kurunegala[4].items():
    print("\t", key, ": ", val)
# Out:
# ADF value :  -5.850232148878149
# P value:  3.603706776152739e-07
# Num of Lags : 10
# Num of Observations used for ADF Regression and Critical Calculation : 1815
# 	 1% :  -3.4339580289794225
# 	 5% :  -2.8631337437669275
# 	 10% :  -2.567618456010139

# %% [markdown]
# #### Auto correlation and correlation plot for Kurunegala

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

pacf = plot_pacf(kurunegala_data["HCHO reading"], lags=25)
acf = plot_acf(kurunegala_data["HCHO reading"], lags=25)

# %% [markdown]
# #### There is a seasonality in the Kurunegala data set

# %% [markdown]
# #### Kurunegala LSTM

# %%
data = pd.read_csv("../NullValueHandled/KurunegalaProperHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
print(data.head())
# Out:
#   Current Date  HCHO reading
# 0   2019-01-01      0.000088
# 1   2019-01-02      0.000137
# 2   2019-01-03      0.000148
# 3   2019-01-04     -0.000002
# 4   2019-01-05      0.000249

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# Assuming 'data' is your DataFrame and you've loaded it successfully

# Preprocess data
data['Current Date'] = pd.to_datetime(data['Current Date'])
data.sort_values(by='Current Date', inplace=True)
data.set_index('Current Date', inplace=True)

# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]

# Normalize the data
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# Define function to create sequences for RNN
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length]) 
    return np.array(X), np.array(y) 

sequence_length = 5
# Create sequences for training and testing data
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)
 
model = Sequential([
    Bidirectional(LSTM(units=500, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    Bidirectional(LSTM(units=400, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=200, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=100, return_sequences=True)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Bidirectional(LSTM(units=10)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

optimizer = RMSprop(learning_rate=0.005) 
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 84s 842ms/step - loss: 0.9823 - mean_squared_error: 0.9823 - val_loss: 0.7231 - val_mean_squared_error: 0.7231
# Epoch 2/100
# 37/37 [==============================] - 15s 400ms/step - loss: 0.8821 - mean_squared_error: 0.8821 - val_loss: 0.7713 - val_mean_squared_error: 0.7713
# Epoch 3/100
# 37/37 [==============================] - 14s 364ms/step - loss: 0.8587 - mean_squared_error: 0.8587 - val_loss: 0.7486 - val_mean_squared_error: 0.7486
# Epoch 4/100
# 37/37 [==============================] - 21s 561ms/step - loss: 0.8567 - mean_squared_error: 0.8567 - val_loss: 0.7961 - val_mean_squared_error: 0.7961
# Epoch 5/100
# 37/37 [==============================] - 21s 557ms/step - loss: 0.8287 - mean_squared_error: 0.8287 - val_loss: 0.6886 - val_mean_squared_error: 0.6886
# Epoch 6/100
# 37/37 [==============================] - 14s 380ms/step - loss: 0.8254 - mean_squared_error: 0.8254 - val_loss: 0.7524 - val_mean_squared_error: 0.7524
# Epoch 7/100
# 37/37 [==============================] - 13s 356ms/step - loss: 0.8127 - mean_squared_error: 0.8127 - val_loss: 0.6648 - val_mean_squared_error: 0.6648
# Epoch 8/100
# 37/37 [==============================] - 12s 340ms/step - loss: 0.8203 - mean_squared_error: 0.8203 - val_loss: 0.7110 - val_mean_squared_error: 0.7110
# Epoch 9/100
# 37/37 [==============================] - 13s 349ms/step - loss: 0.8269 - mean_squared_error: 0.8269 - val_loss: 0.6780 - val_mean_squared_error: 0.6780
# Epoch 10/100
# 37/37 [==============================] - 13s 349ms/step - loss: 0.8169 - mean_squared_error: 0.8169 - val_loss: 0.8954 - val_mean_squared_error: 0.8954
# Epoch 11/100
# 37/37 [==============================] - 13s 362ms/step - loss: 0.8135 - mean_squared_error: 0.8135 - val_loss: 0.7410 - val_mean_squared_error: 0.7410
# Epoch 12/100
# 37/37 [==============================] - 12s 331ms/step - loss: 0.8093 - mean_squared_error: 0.8093 - val_loss: 0.6735 - val_mean_squared_error: 0.6735
# Epoch 13/100
# 37/37 [==============================] - 11s 310ms/step - loss: 0.7925 - mean_squared_error: 0.7925 - val_loss: 0.6663 - val_mean_squared_error: 0.6663
# Epoch 14/100
# 37/37 [==============================] - 12s 325ms/step - loss: 0.8047 - mean_squared_error: 0.8047 - val_loss: 0.6848 - val_mean_squared_error: 0.6848
# Epoch 15/100
# 37/37 [==============================] - 11s 306ms/step - loss: 0.8016 - mean_squared_error: 0.8016 - val_loss: 0.6904 - val_mean_squared_error: 0.6904
# Epoch 16/100
# 37/37 [==============================] - 11s 298ms/step - loss: 0.8011 - mean_squared_error: 0.8011 - val_loss: 0.6769 - val_mean_squared_error: 0.6769
# Epoch 17/100
# 37/37 [==============================] - 12s 313ms/step - loss: 0.8163 - mean_squared_error: 0.8163 - val_loss: 0.7624 - val_mean_squared_error: 0.7624
# Epoch 18/100
# 37/37 [==============================] - 11s 309ms/step - loss: 0.7953 - mean_squared_error: 0.7953 - val_loss: 0.6858 - val_mean_squared_error: 0.6858
# Epoch 19/100
# 37/37 [==============================] - 11s 304ms/step - loss: 0.8002 - mean_squared_error: 0.8002 - val_loss: 0.6922 - val_mean_squared_error: 0.6922
# Epoch 20/100
# 37/37 [==============================] - 12s 314ms/step - loss: 0.8028 - mean_squared_error: 0.8028 - val_loss: 0.7186 - val_mean_squared_error: 0.7186
# Epoch 21/100
# 37/37 [==============================] - 12s 316ms/step - loss: 0.7962 - mean_squared_error: 0.7962 - val_loss: 0.7445 - val_mean_squared_error: 0.7445
# Epoch 22/100
# 37/37 [==============================] - 12s 309ms/step - loss: 0.8000 - mean_squared_error: 0.8000 - val_loss: 0.6874 - val_mean_squared_error: 0.6874
# Epoch 23/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.7916 - mean_squared_error: 0.7916 - val_loss: 0.6811 - val_mean_squared_error: 0.6811
# Epoch 24/100
# 37/37 [==============================] - 4s 112ms/step - loss: 0.7843 - mean_squared_error: 0.7843 - val_loss: 0.6762 - val_mean_squared_error: 0.6762
# Epoch 25/100
# 37/37 [==============================] - 4s 114ms/step - loss: 0.7944 - mean_squared_error: 0.7944 - val_loss: 0.6812 - val_mean_squared_error: 0.6812
# Epoch 26/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.7908 - mean_squared_error: 0.7908 - val_loss: 0.6760 - val_mean_squared_error: 0.6760
# Epoch 27/100
# 37/37 [==============================] - 5s 122ms/step - loss: 0.8013 - mean_squared_error: 0.8013 - val_loss: 0.7002 - val_mean_squared_error: 0.7002
# Epoch 28/100
# 37/37 [==============================] - 5s 141ms/step - loss: 0.7845 - mean_squared_error: 0.7845 - val_loss: 0.7089 - val_mean_squared_error: 0.7089
# Epoch 29/100
# 37/37 [==============================] - 5s 143ms/step - loss: 0.7929 - mean_squared_error: 0.7929 - val_loss: 0.7026 - val_mean_squared_error: 0.7026
# Epoch 30/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.7797 - mean_squared_error: 0.7797 - val_loss: 0.6957 - val_mean_squared_error: 0.6957
# Epoch 31/100
# 37/37 [==============================] - 5s 127ms/step - loss: 0.7825 - mean_squared_error: 0.7825 - val_loss: 0.6890 - val_mean_squared_error: 0.6890
# Epoch 32/100
# 37/37 [==============================] - 5s 122ms/step - loss: 0.7893 - mean_squared_error: 0.7893 - val_loss: 0.6904 - val_mean_squared_error: 0.6904
# Epoch 33/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.7802 - mean_squared_error: 0.7802 - val_loss: 0.7142 - val_mean_squared_error: 0.7142
# Epoch 34/100
# 37/37 [==============================] - 4s 114ms/step - loss: 0.7753 - mean_squared_error: 0.7753 - val_loss: 0.7258 - val_mean_squared_error: 0.7258
# Epoch 35/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.7718 - mean_squared_error: 0.7718 - val_loss: 0.7263 - val_mean_squared_error: 0.7263
# Epoch 36/100
# 37/37 [==============================] - 5s 127ms/step - loss: 0.7742 - mean_squared_error: 0.7742 - val_loss: 0.6838 - val_mean_squared_error: 0.6838
# Epoch 37/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.7607 - mean_squared_error: 0.7607 - val_loss: 0.6993 - val_mean_squared_error: 0.6993
# Epoch 38/100
# 37/37 [==============================] - 5s 123ms/step - loss: 0.7597 - mean_squared_error: 0.7597 - val_loss: 0.7368 - val_mean_squared_error: 0.7368
# Epoch 39/100
# 37/37 [==============================] - 5s 123ms/step - loss: 0.7569 - mean_squared_error: 0.7569 - val_loss: 0.7275 - val_mean_squared_error: 0.7275
# Epoch 40/100
# 37/37 [==============================] - 5s 141ms/step - loss: 0.7627 - mean_squared_error: 0.7627 - val_loss: 0.7317 - val_mean_squared_error: 0.7317
# Epoch 41/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.7622 - mean_squared_error: 0.7622 - val_loss: 0.7306 - val_mean_squared_error: 0.7306
# Epoch 42/100
# 37/37 [==============================] - 5s 125ms/step - loss: 0.7441 - mean_squared_error: 0.7441 - val_loss: 0.7350 - val_mean_squared_error: 0.7350
# Epoch 43/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0.7399 - mean_squared_error: 0.7399 - val_loss: 0.7647 - val_mean_squared_error: 0.7647
# Epoch 44/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.7509 - mean_squared_error: 0.7509 - val_loss: 0.7361 - val_mean_squared_error: 0.7361
# Epoch 45/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.7488 - mean_squared_error: 0.7488 - val_loss: 0.7430 - val_mean_squared_error: 0.7430
# Epoch 46/100
# 37/37 [==============================] - 5s 134ms/step - loss: 0.7289 - mean_squared_error: 0.7289 - val_loss: 0.6927 - val_mean_squared_error: 0.6927
# Epoch 47/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.7546 - mean_squared_error: 0.7546 - val_loss: 0.7053 - val_mean_squared_error: 0.7053
# Epoch 48/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.7326 - mean_squared_error: 0.7326 - val_loss: 0.7633 - val_mean_squared_error: 0.7633
# Epoch 49/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0.7526 - mean_squared_error: 0.7526 - val_loss: 0.7317 - val_mean_squared_error: 0.7317
# Epoch 50/100
# 37/37 [==============================] - 5s 122ms/step - loss: 0.7340 - mean_squared_error: 0.7340 - val_loss: 0.6908 - val_mean_squared_error: 0.6908
# Epoch 51/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.7307 - mean_squared_error: 0.7307 - val_loss: 0.7365 - val_mean_squared_error: 0.7365
# Epoch 52/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0.7310 - mean_squared_error: 0.7310 - val_loss: 0.7144 - val_mean_squared_error: 0.7144
# Epoch 53/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.7195 - mean_squared_error: 0.7195 - val_loss: 0.7407 - val_mean_squared_error: 0.7407
# Epoch 54/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.7290 - mean_squared_error: 0.7290 - val_loss: 0.7516 - val_mean_squared_error: 0.7516
# Epoch 55/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.7011 - mean_squared_error: 0.7011 - val_loss: 0.7449 - val_mean_squared_error: 0.7449
# Epoch 56/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.7065 - mean_squared_error: 0.7065 - val_loss: 0.7906 - val_mean_squared_error: 0.7906
# Epoch 57/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.6995 - mean_squared_error: 0.6995 - val_loss: 0.7754 - val_mean_squared_error: 0.7754
# Epoch 58/100
# 37/37 [==============================] - 5s 123ms/step - loss: 0.6818 - mean_squared_error: 0.6818 - val_loss: 0.8008 - val_mean_squared_error: 0.8008
# Epoch 59/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.6970 - mean_squared_error: 0.6970 - val_loss: 0.7115 - val_mean_squared_error: 0.7115
# Epoch 60/100
# 37/37 [==============================] - 5s 123ms/step - loss: 0.6879 - mean_squared_error: 0.6879 - val_loss: 0.7533 - val_mean_squared_error: 0.7533
# Epoch 61/100
# 37/37 [==============================] - 5s 127ms/step - loss: 0.6611 - mean_squared_error: 0.6611 - val_loss: 0.7558 - val_mean_squared_error: 0.7558
# Epoch 62/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.6533 - mean_squared_error: 0.6533 - val_loss: 0.7854 - val_mean_squared_error: 0.7854
# Epoch 63/100
# 37/37 [==============================] - 5s 134ms/step - loss: 0.6814 - mean_squared_error: 0.6814 - val_loss: 0.7620 - val_mean_squared_error: 0.7620
# Epoch 64/100
# 37/37 [==============================] - 5s 125ms/step - loss: 0.6692 - mean_squared_error: 0.6692 - val_loss: 0.7562 - val_mean_squared_error: 0.7562
# Epoch 65/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.6567 - mean_squared_error: 0.6567 - val_loss: 0.7473 - val_mean_squared_error: 0.7473
# Epoch 66/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.6299 - mean_squared_error: 0.6299 - val_loss: 0.7975 - val_mean_squared_error: 0.7975
# Epoch 67/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.6135 - mean_squared_error: 0.6135 - val_loss: 0.8129 - val_mean_squared_error: 0.8129
# Epoch 68/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.6211 - mean_squared_error: 0.6211 - val_loss: 0.7939 - val_mean_squared_error: 0.7939
# Epoch 69/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.6293 - mean_squared_error: 0.6293 - val_loss: 0.8487 - val_mean_squared_error: 0.8487
# Epoch 70/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.5721 - mean_squared_error: 0.5721 - val_loss: 0.8251 - val_mean_squared_error: 0.8251
# Epoch 71/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.6490 - mean_squared_error: 0.6490 - val_loss: 0.7750 - val_mean_squared_error: 0.7750
# Epoch 72/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.5946 - mean_squared_error: 0.5946 - val_loss: 0.8507 - val_mean_squared_error: 0.8507
# Epoch 73/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.6093 - mean_squared_error: 0.6093 - val_loss: 0.8089 - val_mean_squared_error: 0.8089
# Epoch 74/100
# 37/37 [==============================] - 5s 135ms/step - loss: 0.6004 - mean_squared_error: 0.6004 - val_loss: 0.7984 - val_mean_squared_error: 0.7984
# Epoch 75/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.5787 - mean_squared_error: 0.5787 - val_loss: 0.8542 - val_mean_squared_error: 0.8542
# Epoch 76/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.5630 - mean_squared_error: 0.5630 - val_loss: 0.8081 - val_mean_squared_error: 0.8081
# Epoch 77/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.5728 - mean_squared_error: 0.5728 - val_loss: 0.8656 - val_mean_squared_error: 0.8656
# Epoch 78/100
# 37/37 [==============================] - 5s 132ms/step - loss: 0.5357 - mean_squared_error: 0.5357 - val_loss: 0.8565 - val_mean_squared_error: 0.8565
# Epoch 79/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.5551 - mean_squared_error: 0.5551 - val_loss: 0.8508 - val_mean_squared_error: 0.8508
# Epoch 80/100
# 37/37 [==============================] - 5s 138ms/step - loss: 0.5585 - mean_squared_error: 0.5585 - val_loss: 0.8493 - val_mean_squared_error: 0.8493
# Epoch 81/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.5082 - mean_squared_error: 0.5082 - val_loss: 0.8754 - val_mean_squared_error: 0.8754
# Epoch 82/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.5070 - mean_squared_error: 0.5070 - val_loss: 0.9127 - val_mean_squared_error: 0.9127
# Epoch 83/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.4943 - mean_squared_error: 0.4943 - val_loss: 0.8698 - val_mean_squared_error: 0.8698
# Epoch 84/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.4733 - mean_squared_error: 0.4733 - val_loss: 0.8830 - val_mean_squared_error: 0.8830
# Epoch 85/100
# 37/37 [==============================] - 4s 122ms/step - loss: 0.4604 - mean_squared_error: 0.4604 - val_loss: 0.8822 - val_mean_squared_error: 0.8822
# Epoch 86/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.4635 - mean_squared_error: 0.4635 - val_loss: 0.8953 - val_mean_squared_error: 0.8953
# Epoch 87/100
# 37/37 [==============================] - 5s 122ms/step - loss: 0.4446 - mean_squared_error: 0.4446 - val_loss: 0.9299 - val_mean_squared_error: 0.9299
# Epoch 88/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.4628 - mean_squared_error: 0.4628 - val_loss: 0.9355 - val_mean_squared_error: 0.9355
# Epoch 89/100
# 37/37 [==============================] - 4s 118ms/step - loss: 0.4127 - mean_squared_error: 0.4127 - val_loss: 0.9000 - val_mean_squared_error: 0.9000
# Epoch 90/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.3748 - mean_squared_error: 0.3748 - val_loss: 0.9863 - val_mean_squared_error: 0.9863
# Epoch 91/100
# 37/37 [==============================] - 4s 117ms/step - loss: 0.3823 - mean_squared_error: 0.3823 - val_loss: 0.9848 - val_mean_squared_error: 0.9848
# Epoch 92/100
# 37/37 [==============================] - 4s 119ms/step - loss: 0.3649 - mean_squared_error: 0.3649 - val_loss: 0.9965 - val_mean_squared_error: 0.9965
# Epoch 93/100
# 37/37 [==============================] - 4s 116ms/step - loss: 0.3552 - mean_squared_error: 0.3552 - val_loss: 0.9584 - val_mean_squared_error: 0.9584
# Epoch 94/100
# 37/37 [==============================] - 4s 114ms/step - loss: 0.3825 - mean_squared_error: 0.3825 - val_loss: 0.8569 - val_mean_squared_error: 0.8569
# Epoch 95/100
# 37/37 [==============================] - 5s 128ms/step - loss: 0.3517 - mean_squared_error: 0.3517 - val_loss: 0.9968 - val_mean_squared_error: 0.9968
# Epoch 96/100
# 37/37 [==============================] - 4s 122ms/step - loss: 0.3285 - mean_squared_error: 0.3285 - val_loss: 0.9887 - val_mean_squared_error: 0.9887
# Epoch 97/100
# 37/37 [==============================] - 4s 121ms/step - loss: 0.3176 - mean_squared_error: 0.3176 - val_loss: 0.9484 - val_mean_squared_error: 0.9484
# Epoch 98/100
# 37/37 [==============================] - 5s 133ms/step - loss: 0.3349 - mean_squared_error: 0.3349 - val_loss: 1.0050 - val_mean_squared_error: 1.0050
# Epoch 99/100
# 37/37 [==============================] - 5s 128ms/step - loss: 0.2935 - mean_squared_error: 0.2935 - val_loss: 0.9400 - val_mean_squared_error: 0.9400
# Epoch 100/100
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2833 - mean_squared_error: 0.2833 - val_loss: 0.9275 - val_mean_squared_error: 0.9275

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_test)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 5s 35ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_train)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 46/46 [==============================] - 1s 32ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled_test = model.predict(X_test)

# Inverse transform predictions and actual values to original scale for testing data
predictions_test = scaler.inverse_transform(predictions_scaled_test)
actual_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Predict values for training data
predictions_scaled_train = model.predict(X_train)

# Inverse transform predictions and actual values to original scale for training data
predictions_train = scaler.inverse_transform(predictions_scaled_train)
actual_train = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual_train, label='Actual (Train)', color='blue')
plt.plot(predictions_train, label='Predicted (Train)', color='orange')
plt.plot(len(predictions_train) + np.arange(len(predictions_test)), predictions_test, label='Predicted (Test)', color='red')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 32ms/step
# 46/46 [==============================] - 1s 31ms/step

# %% [markdown]
# #### Model Testing Scores

# %%
y_test = actual
predicted_values = predictions.reshape(-1, 1)
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): 0.6443692206090519
# Mean Absolute Error (MAE): 2.8479143137776713e-05
# Mean Squared Error (MSE): 1.6546962253276127e-09
# Root Mean Squared Error (RMSE): 4.067795748716512e-05
# Median Absolute Error: 1.9996354830906156e-05
# Explained Variance Score: 0.6456126878718855

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare your data
data = pd.read_csv("../NullValueHandled/KurunegalaProperHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data.rename(columns={'Current Date': 'ds', 'HCHO reading': 'y'}, inplace=True)
data['ds'] = pd.to_datetime(data['ds'])

# Define holidays
holidays = pd.DataFrame({
    'holiday': 'covid',
    'ds': pd.to_datetime(['2020-03-15', '2021-12-31']), 
    'lower_window': 0,
    'upper_window': 1,
})

train_size = int(0.90 * len(data)) 
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Initialize and fit the Prophet model with holidays
model = Prophet(holidays=holidays,
               changepoint_prior_scale=0.3, 
               seasonality_prior_scale=5,) 
model.fit(train_data)

# Create a dataframe for future dates predictions
future = model.make_future_dataframe(periods=365)

# Make predictions
forecast = model.predict(future)

# Plot the forecast
fig1 = model.plot(forecast)
ax = fig1.gca()

# Overlay actual data
ax.plot(train_data['ds'], train_data['y'], 'k.', label='Actual Data')

plt.show()
# Out:
# 00:08:29 - cmdstanpy - INFO - Chain [1] start processing
# 00:08:29 - cmdstanpy - INFO - Chain [1] done processing

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot actual data
sns.lineplot(data=train_data, x='ds', y='y', label='Actual Data', color='black', marker='o', linestyle='None')

# Plot yhat - forecast
sns.lineplot(data=forecast, x='ds', y='yhat', label='Forecast (yhat)', color='#6a0dad')  # Purple

# Plot yhat_upper
sns.lineplot(data=forecast, x='ds', y='yhat_upper', label='Forecast Upper Bound (yhat_upper)', color='#33a1ff')  # Teal

# Plot yhat_lower
sns.lineplot(data=forecast, x='ds', y='yhat_lower', label='Forecast Lower Bound (yhat_lower)', color='#00e6e6')  # Light Teal

plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='#d9b3ff', alpha=0.2, label='Confidence Interval')  # Light Purple

plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('HCHO Reading Forecast')

# Adjust legend
plt.legend()

plt.show()

# %%
# Plot the forecast components
fig2 = model.plot_components(forecast)

# %%
y_test = test_data['y']
predicted_values = forecast.loc[forecast['ds'].isin(test_data['ds']), 'yhat']  # Extract forecasted values for test period
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): -0.25792078454468204
# Mean Absolute Error (MAE): 5.181082567927416e-05
# Mean Squared Error (MSE): 4.260705314001012e-09
# Root Mean Squared Error (RMSE): 6.527407842322259e-05
# Median Absolute Error: 4.708687601755261e-05
# Explained Variance Score: 0.07048579003635203

# %% [markdown]
# #### Kurunegala Multi Variate Model

# %%
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Current Date          1826 non-null   object
#  1   HCHO reading          1826 non-null   float64
#  2   Region                1826 non-null   object
#  3   LATITUDE              1826 non-null   float64
#  4   LONGITUDE             1826 non-null   float64
#  5   ELEVATION             1826 non-null   float64
#  6   PRCP                  1826 non-null   float64
#  7   TAVG                  1826 non-null   float64
#  8   TMAX                  1826 non-null   float64
#  9   TMIN                  1826 non-null   float64
#  10  Population            1826 non-null   int64
#  11  Area_sq_km            1826 non-null   int64
#  12  population_density    1826 non-null   float64
#  13  Proximity(km)         1826 non-null   float64
#  14  carbon_monoxide       1826 non-null   float64
#  15  nitogen_dioxide       1826 non-null   float64
#  16  ozone                 1826 non-null   float64
#  17  new_covid_patients    1826 non-null   int64
#  18  total_covid_patients  1826 non-null   int64
#  19  lockdown_status       1826 non-null   object
#  20  covid_range_status    1826 non-null   object
# dtypes: float64(13), int64(4), object(4)
# memory usage: 299.7+ KB

# %%
# Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data.head()
# Out:
#   Current Date  HCHO reading             Region  LATITUDE  LONGITUDE  \
# 0   2019-01-01      0.000088  Kurunegala Proper     7.467     80.367
# 1   2019-01-02      0.000137  Kurunegala Proper     7.467     80.367
# 2   2019-01-03      0.000148  Kurunegala Proper     7.467     80.367
# 3   2019-01-04     -0.000002  Kurunegala Proper     7.467     80.367
# 4   2019-01-05      0.000249  Kurunegala Proper     7.467     80.367
#
#    ELEVATION  PRCP  TAVG  TMAX  TMIN  Population  Area_sq_km  \
# 0      116.0   0.0  78.0  87.0  72.0     1719000        4816
# 1      116.0   0.0  78.0  87.0  72.0     1719000        4816
# 2      116.0   0.0  81.0  87.0  71.0     1719000        4816
# 3      116.0   0.0  83.0  88.0  69.0     1719000        4816
# 4      116.0   0.0  84.0  90.0  65.0     1719000        4816
#
#    population_density  Proximity(km)  carbon_monoxide  nitogen_dioxide  \
# 0              356.94           59.5         0.035947         0.000007
# 1              356.94           59.5         0.036163         0.000011
# 2              356.94           59.5         0.032443         0.000010
# 3              356.94           59.5         0.034312         0.000009
# 4              356.94           59.5         0.033251         0.000009
#
#       ozone  new_covid_patients  total_covid_patients lockdown_status  \
# 0  0.115939                   0                     0          Before
# 1  0.115939                   0                     0          Before
# 2  0.115939                   0                     0          Before
# 3  0.115939                   0                     0          Before
# 4  0.115939                   0                     0          Before
#
#   covid_range_status
# 0             Before
# 1             Before
# 2             Before
# 3             Before
# 4             Before

# %% [markdown]
# #### remove constant data

# %%
data.columns
# Out:
# Index(['Current Date', 'HCHO reading', 'Region', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 'Area_sq_km',
#        'population_density', 'Proximity(km)', 'carbon_monoxide',
#        'nitogen_dioxide', 'ozone', 'new_covid_patients',
#        'total_covid_patients', 'lockdown_status', 'covid_range_status'],
#       dtype='object')

# %%
data.drop(columns=['Region', 'LATITUDE', 'LONGITUDE',
       'ELEVATION','Area_sq_km', 'Proximity(km)'], inplace=True)

# %%
data.head()
# Out:
#   Current Date  HCHO reading  PRCP  TAVG  TMAX  TMIN  Population  \
# 0   2019-01-01      0.000088   0.0  78.0  87.0  72.0     1719000
# 1   2019-01-02      0.000137   0.0  78.0  87.0  72.0     1719000
# 2   2019-01-03      0.000148   0.0  81.0  87.0  71.0     1719000
# 3   2019-01-04     -0.000002   0.0  83.0  88.0  69.0     1719000
# 4   2019-01-05      0.000249   0.0  84.0  90.0  65.0     1719000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              356.94         0.035947         0.000007  0.115939
# 1              356.94         0.036163         0.000011  0.115939
# 2              356.94         0.032443         0.000010  0.115939
# 3              356.94         0.034312         0.000009  0.115939
# 4              356.94         0.033251         0.000009  0.115939
#
#    new_covid_patients  total_covid_patients lockdown_status covid_range_status
# 0                   0                     0          Before             Before
# 1                   0                     0          Before             Before
# 2                   0                     0          Before             Before
# 3                   0                     0          Before             Before
# 4                   0                     0          Before             Before

# %% [markdown]
# #### Encode Categorical data

# %%
from sklearn.preprocessing import LabelEncoder
 
dates = data["Current Date"]

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate through each column in the DataFrame
for column in data.columns:
    # Check if the column is of categorical type
    if data[column].dtype == 'object':
        # Fit label encoder and transform values
        data[column] = label_encoder.fit_transform(data[column])

# %%
data["Current Date"] = dates
data.head()
# Out:
#   Current Date  HCHO reading  PRCP  TAVG  TMAX  TMIN  Population  \
# 0   2019-01-01      0.000088   0.0  78.0  87.0  72.0     1719000
# 1   2019-01-02      0.000137   0.0  78.0  87.0  72.0     1719000
# 2   2019-01-03      0.000148   0.0  81.0  87.0  71.0     1719000
# 3   2019-01-04     -0.000002   0.0  83.0  88.0  69.0     1719000
# 4   2019-01-05      0.000249   0.0  84.0  90.0  65.0     1719000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              356.94         0.035947         0.000007  0.115939
# 1              356.94         0.036163         0.000011  0.115939
# 2              356.94         0.032443         0.000010  0.115939
# 3              356.94         0.034312         0.000009  0.115939
# 4              356.94         0.033251         0.000009  0.115939
#
#    new_covid_patients  total_covid_patients  lockdown_status  \
# 0                   0                     0                1
# 1                   0                     0                1
# 2                   0                     0                1
# 3                   0                     0                1
# 4                   0                     0                1
#
#    covid_range_status
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# #### Check correlations

# %%
corr = data.corr(numeric_only=True)["HCHO reading"]
corr = pd.DataFrame(corr)
corr
# Out:
#                       HCHO reading
# HCHO reading              1.000000
# PRCP                     -0.020175
# TAVG                      0.174568
# TMAX                      0.342388
# TMIN                     -0.095334
# Population               -0.037514
# population_density       -0.037528
# carbon_monoxide           0.276864
# nitogen_dioxide           0.007006
# ozone                    -0.075194
# new_covid_patients       -0.057518
# total_covid_patients     -0.074258
# lockdown_status           0.037139
# covid_range_status        0.018257

# %%
corr.to_csv("../OtherData/KurunegalaCorrelationData.csv")

# %%
data.shape
# Out:
# (1826, 15)

# %% [markdown]
# #### remove covid range status

# %%
data.drop(columns=["covid_range_status"], inplace=True)

# %% [markdown]
# #### Devide X and Y

# %%
X = data.drop(columns=["HCHO reading"])
y = data["HCHO reading"]

# %%
X.head()
# Out:
#   Current Date  PRCP  TAVG  TMAX  TMIN  Population  population_density  \
# 0   2019-01-01   0.0  78.0  87.0  72.0     1719000              356.94
# 1   2019-01-02   0.0  78.0  87.0  72.0     1719000              356.94
# 2   2019-01-03   0.0  81.0  87.0  71.0     1719000              356.94
# 3   2019-01-04   0.0  83.0  88.0  69.0     1719000              356.94
# 4   2019-01-05   0.0  84.0  90.0  65.0     1719000              356.94
#
#    carbon_monoxide  nitogen_dioxide     ozone  new_covid_patients  \
# 0         0.035947         0.000007  0.115939                   0
# 1         0.036163         0.000011  0.115939                   0
# 2         0.032443         0.000010  0.115939                   0
# 3         0.034312         0.000009  0.115939                   0
# 4         0.033251         0.000009  0.115939                   0
#
#    total_covid_patients  lockdown_status
# 0                     0                1
# 1                     0                1
# 2                     0                1
# 3                     0                1
# 4                     0                1

# %% [markdown]
# #### Select features based on Correlations

# %%
data.corr(numeric_only=True)["HCHO reading"]
# Out:
# HCHO reading            1.000000
# PRCP                   -0.020175
# TAVG                    0.174568
# TMAX                    0.342388
# TMIN                   -0.095334
# Population             -0.037514
# population_density     -0.037528
# carbon_monoxide         0.276864
# nitogen_dioxide         0.007006
# ozone                  -0.075194
# new_covid_patients     -0.057518
# total_covid_patients   -0.074258
# lockdown_status         0.037139
# Name: HCHO reading, dtype: float64

# %%
X = X[["Current Date", "carbon_monoxide","TMAX"]]
X.head()
# Out:
#   Current Date  carbon_monoxide  TMAX
# 0   2019-01-01         0.035947  87.0
# 1   2019-01-02         0.036163  87.0
# 2   2019-01-03         0.032443  87.0
# 3   2019-01-04         0.034312  88.0
# 4   2019-01-05         0.033251  90.0

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Current Date     1826 non-null   object
#  1   carbon_monoxide  1826 non-null   float64
#  2   TMAX             1826 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 42.9+ KB

# %% [markdown]
# #### Standardize, variable data

# %%
from sklearn.preprocessing import StandardScaler
# Select columns of interest
selected_columns = ["carbon_monoxide","TMAX"]

# Convert "Current Date" to datetime format
data["Current Date"] = pd.to_datetime(data["Current Date"])

# Separate the "Current Date" column
current_date = data["Current Date"]

# Select only the columns you're interested in for standardization
X = X[selected_columns]

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the scaler on the data
X_scaled = scaler.fit_transform(X)

# Convert the scaled data back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=selected_columns)

# Concatenate "Current Date" column with the scaled data
X = pd.concat([current_date, X_scaled_df], axis=1)

X.set_index("Current Date", inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2019-01-01 to 2023-12-31
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carbon_monoxide  1826 non-null   float64
#  1   TMAX             1826 non-null   float64
# dtypes: float64(2)
# memory usage: 42.8 KB

# %% [markdown]
# ##### Standardize target variable

# %%
y = data['HCHO reading']

y.head()
# Out:
# 0    0.000088
# 1    0.000137
# 2    0.000148
# 3   -0.000002
# 4    0.000249
# Name: HCHO reading, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_y = MinMaxScaler()
y_scaled = np.array(scaler_y.fit_transform(y.values.reshape(-1, 1)), ndmin=1)

# %%
X_scaled = X

# %%
plt.figure(figsize=(20, 8))
plt.plot(scaler_y.inverse_transform(y_scaled))

# %%
print(X_scaled.head())
# Out:
#               carbon_monoxide      TMAX
# Current Date
# 2019-01-01           0.781534 -0.851669
# 2019-01-02           0.815476 -0.851669
# 2019-01-03           0.231763 -0.851669
# 2019-01-04           0.525000 -0.591436
# 2019-01-05           0.358602 -0.070972

# %% [markdown]
# #### Apply multivariate time series model

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L1
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import MeanAbsoluteError


# Now, split the data into training and testing sets
split_ratio = 0.8
split_index = int(len(X_scaled) * split_ratio)

X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
y_train, y_test = y_scaled[:split_index], y_scaled[split_index:]


model = Sequential([
    Bidirectional(LSTM(units=120, return_sequences=True, activation="relu"), input_shape=(X_train.shape[1],1)),
    Dropout(0.2),
    Bidirectional(LSTM(units=5)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

# Compilation of the model
optimizer = Adam(learning_rate=0.008)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

# Train the model with validation data
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 46/46 [==============================] - 10s 48ms/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 2/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 3/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 4/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 5/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 6/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 7/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 8/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 9/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 10/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 11/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 12/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 13/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 14/150
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 15/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 16/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 17/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 18/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 19/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 20/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 21/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 22/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 23/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 24/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 25/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 26/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 27/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 28/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 29/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 30/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 31/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 32/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 33/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 34/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 35/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 36/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 37/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 38/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 39/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 40/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 41/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 42/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 43/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 44/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 45/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 46/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 47/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 48/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 49/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 50/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 51/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 52/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 53/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 54/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 55/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 56/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 57/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 58/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 59/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 60/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 61/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 62/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 63/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 64/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 65/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 66/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 67/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 68/150
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 69/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 70/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 71/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 72/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 73/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 74/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 75/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 76/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 77/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 78/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 79/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 80/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 81/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 82/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 83/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 84/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 85/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 86/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 87/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 88/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 89/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 90/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 91/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 92/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 93/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 94/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 95/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 96/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 97/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 98/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 99/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 100/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 101/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 102/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 103/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 104/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 105/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 106/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 107/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 108/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 109/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 110/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 111/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 112/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 113/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 114/150
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 115/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 116/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 117/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 118/150
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 119/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 120/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 121/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 122/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 123/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 124/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 125/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 126/150
# 46/46 [==============================] - 0s 10ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 127/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 128/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 129/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 130/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 131/150
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 132/150
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 133/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 134/150
# 46/46 [==============================] - 1s 12ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 135/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 136/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 137/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 138/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 139/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 140/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 141/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 142/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 143/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 144/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 145/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 146/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 147/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 148/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 149/150
# 46/46 [==============================] - 0s 11ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 150/150
# 46/46 [==============================] - 1s 11ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0204 - val_mean_squared_error: 0.0204

# %%
# Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Make predictions
predictions = model.predict(X_test)

# Optionally, you can inverse transform the predictions to get them back to the original scale
predictions_inv = scaler_y.inverse_transform(predictions)
actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))
import matplotlib.pyplot as plt

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions_inv, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0204 - mean_squared_error: 0.0204
# Test Loss: [0.02039891481399536, 0.02039891481399536]
# 12/12 [==============================] - 2s 4ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled_test = model.predict(X_test)

# Inverse transform predictions and actual values to original scale for testing data
predictions_test = scaler_y.inverse_transform(predictions)
actual_test = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# Predict values for training data
predictions_scaled_train = model.predict(X_train)

# Inverse transform predictions and actual values to original scale for training data
predictions_train = scaler_y.inverse_transform(predictions_scaled_train)
actual_train = scaler_y.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(20, 8))
plt.plot(data["HCHO reading"], label='Actual (Train)', color='blue')
plt.plot(predictions_train, label='Predicted (Train)', color='orange')
plt.plot(len(predictions_train) + np.arange(len(predictions_test)), predictions_test, label='Predicted (Test)', color='red')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 4ms/step

# %%
r2 = (r2_score(actual_test, predictions_test))
mae = mean_absolute_error(actual_test, predictions_test)
mse = mean_squared_error(actual_test, predictions_test) 
rmse = mean_squared_error(actual_test, predictions_test, squared=False)
median_absolute = median_absolute_error(actual_test,predictions_test)
explained_variance = explained_variance_score(actual_test, predictions_test)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): 0.14525245969916867
# Mean Absolute Error (MAE): 4.565564405339549e-05
# Mean Squared Error (MSE): 3.4029150011986713e-09
# Root Mean Squared Error (RMSE): 5.833450952222596e-05
# Median Absolute Error: 3.737363357035195e-05
# Explained Variance Score: 0.14550660384496106

# %% [markdown]
# #### Single Variate Time Series Models

# %% [markdown]
# ##### ARIMA model for Nuwara Eliya

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot as plt
from pmdarima import auto_arima

# %%
# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
   'carbon_monoxide': data["carbon_monoxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# %%
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]
# Find the best parameters using auto_arima

# %%
# Fit the SARIMAX Model
exog_train = train[['carbon_monoxide', 'TMAX']]
endog_train = train['HCHO reading']

model = SARIMAX(endog_train, exog=exog_train, order=(1, 0, 1), seasonal_order=(0, 0, 0, 0))
model_fit = model.fit(disp=False)

# Forecast
exog_test = test[['carbon_monoxide', 'TMAX']]
endog_test = test['HCHO reading']
predictions = model_fit.forecast(steps=len(test), exog=exog_test)

# %%
mse = mean_squared_error(endog_test, predictions)
print('MSE: ', mse)

# Plotting the results
plt.figure(figsize=(10,5))
plt.plot(endog_test.index, endog_test, label='Actual')
plt.plot(endog_test.index, predictions, label='Forecasted', color='red')
plt.legend()
plt.show()
# Out:
# MSE:  3.6320908866281253e-09

# %%
# Predict in-sample for the training data
in_sample_predictions = model_fit.predict(start=train.index[0], end=train.index[-1], exog=exog_train)

# Your existing code already handles forecasting the test data:
predictions = model_fit.forecast(steps=len(test), exog=exog_test)


in_sample_preds_series = pd.Series(in_sample_predictions, index=train.index)
predictions_series = pd.Series(predictions, index=test.index)

import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 6))

# Plot training data
plt.plot(train['HCHO reading'], label='Training Data', color='blue')

# Plot testing data
plt.plot(test['HCHO reading'], label='Actual Test Data', color='green')

# Plot in-sample predictions
plt.plot(in_sample_preds_series, label='In-sample Predictions', color='orange', linestyle='--')

# Plot out-of-sample predictions
plt.plot(predictions_series, label='sample Predictions', color='red', linestyle='--')

plt.title('Actual and Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Calculate metrics for the training data
mse_train = mean_squared_error(train['HCHO reading'], in_sample_predictions)
mae_train = mean_absolute_error(train['HCHO reading'], in_sample_predictions)
r2_train = r2_score(train['HCHO reading'], in_sample_predictions)

print("Training Data Metrics:")
print("MSE:", mse_train)
print("MAE:", mae_train)
print("R^2 Score:", r2_train)
# Out:
# Training Data Metrics:
# MSE: 3.543831479468887e-09
# MAE: 4.344501932858666e-05
# R^2 Score: 0.23950624901996198

# %% [markdown]
# ### Single variate models for Kurunegala

# %% [markdown]
# #### AR model Kurunegala

# %%
from statsmodels.tsa.arima.model import ARIMA
import pandas as pd
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

data_dict = {
    'carbon_monoxide': data["carbon_monoxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')


# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# ARIMA example
yhat_ar = [] 

for t in tqdm(range(len(test['HCHO reading']))):
    temp_train = data['HCHO reading'][:train_size + t]
    model = ARIMA(temp_train, order=(6, 0, 0))  # AR model with p=1, d=0, q=0 (since it's AR)
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=1)[0]  # Forecasting 1 step ahead
    yhat_ar.append(predictions)

yhat_ar = pd.Series(yhat_ar, index=test.index)
ar_mse = mean_squared_error(test['HCHO reading'], yhat_ar)

# Print or store the results
print("ARIMA MSE:", ar_mse)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 366/366 [11:27<00:00,  1.88s/it]
# ARIMA MSE: 3.3258456487297313e-09

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_ar, label='ARIMA Predictions', color='red')
plt.title('AR Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(20, 8))
plt.plot(train.index, train['HCHO reading'], label='Train')
plt.plot(test.index, test['HCHO reading'], label='Test')
plt.plot(test.index, yhat_ar, label='Predicted')

plt.title('AR Forecast')
plt.xlabel('Date')
plt.ylabel('HCHO reading')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_ar)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_ar)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_ar) 

rmse = mean_squared_error(test['HCHO reading'], yhat_ar, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_ar)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_ar) 


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# Mean Absolute Error (MAE): 4.2079365162275934e-05
# Mean Squared Error (MSE): 3.3258456487297313e-09
# R-squared (R2) Score: 0.1646108155300372
# Root Mean Squared Error (RMSE): 5.7670145211623415e-05
# Median Absolute Error: 3.059827036251097e-05
# Explained Variance Score: 0.16470087550505685

# %% [markdown]
# #### Kurunegala SARIMA model

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
    'carbon_monoxide': data["carbon_monoxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# SARIMA example using auto_arima
model = auto_arima(train['HCHO reading'], exogenous=train[['carbon_monoxide', 'TMAX']],
                   seasonal=True, m=12,  # assuming monthly seasonality
                   trace=True)  # to display the model selection process
model_fit = model.fit(train['HCHO reading'], exogenous=train[['carbon_monoxide', 'TMAX']])

# Forecasting
forecast = model_fit.predict(n_periods=len(test), exogenous=test[['carbon_monoxide', 'TMAX']])

# Calculating MSE
sarima_mse = mean_squared_error(test['HCHO reading'], forecast)

# Print or store the results
print("SARIMA MSE:", sarima_mse)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-24224.909, Time=3.24 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-23516.295, Time=0.26 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-23849.107, Time=1.28 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-24158.132, Time=15.44 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-23518.303, Time=0.33 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-24226.293, Time=2.55 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-24231.426, Time=0.82 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-24229.408, Time=15.59 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-24230.509, Time=0.59 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=-24182.193, Time=4.80 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=-24229.091, Time=0.83 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=-24231.238, Time=0.92 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-24190.375, Time=5.40 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=-23500.669, Time=2.19 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=-24138.135, Time=2.69 sec
#  ARIMA(3,1,3)(0,0,0)[12] intercept   : AIC=-24231.605, Time=0.98 sec
#  ARIMA(3,1,3)(1,0,0)[12] intercept   : AIC=-24229.642, Time=2.51 sec
#  ARIMA(3,1,3)(0,0,1)[12] intercept   : AIC=-24226.644, Time=6.50 sec
#  ARIMA(3,1,3)(1,0,1)[12] intercept   : AIC=-24225.290, Time=3.96 sec
#  ARIMA(4,1,3)(0,0,0)[12] intercept   : AIC=-24231.190, Time=2.07 sec
#  ARIMA(3,1,4)(0,0,0)[12] intercept   : AIC=-24228.433, Time=1.19 sec
#  ARIMA(2,1,4)(0,0,0)[12] intercept   : AIC=-24230.464, Time=1.06 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=-24227.794, Time=5.09 sec
#  ARIMA(4,1,4)(0,0,0)[12] intercept   : AIC=-24226.118, Time=1.40 sec
#  ARIMA(3,1,3)(0,0,0)[12]             : AIC=-24206.148, Time=4.22 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[12] intercept
# Total fit time: 85.958 seconds
# SARIMA MSE: 4.0647955612767205e-09

# %% [markdown]
# #### ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
   'carbon_monoxide': data["carbon_monoxide"],
   'TMAX': data["TMAX"],
   'HCHO reading': data["HCHO reading"]
}

data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# ARIMA example
yhat_arma = []

for t in tqdm(range(len(test['HCHO reading']))):
    temp_train = data['HCHO reading'][:train_size + t]
    model = ARIMA(temp_train, order=(1, 0, 1))  # ARMA model with p=1,d=0,  q=1
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=1)[0]
    yhat_arma.append(predictions)

yhat_arma = pd.Series(yhat_arma, index=test.index)
arma_mse = mean_squared_error(test['HCHO reading'], yhat_arma)

# Print or store the results
print("ARIMA MSE:", arma_mse)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 366/366 [12:14<00:00,  2.01s/it]
# ARIMA MSE: 3.3537400210314997e-09

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_arma, label='ARIMA Predictions', color='red')
plt.title('ARIMA Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_arma, label='ARIMA Predictions', color='red')
plt.title('ARIMA Model - Test Data vs. Predictions')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_arma)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_arma)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_arma)

rmse = mean_squared_error(test['HCHO reading'], yhat_arma, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_arma)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_arma)


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# Mean Absolute Error (MAE): 4.22171946740143e-05
# Mean Squared Error (MSE): 3.3537400210314997e-09
# R-squared (R2) Score: 0.15760427963220436
# Root Mean Squared Error (RMSE): 5.791148436218415e-05
# Median Absolute Error: 3.0107689464651415e-05
# Explained Variance Score: 0.15771897158221915

# %% [markdown]
# #### Single Variate SARIMA model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/kurunegalaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
   'carbon_monoxide': data["carbon_monoxide"],
   'TMAX': data["TMAX"],
   'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# SARIMA example
yhat_sarima = []

for t in tqdm(range(len(test['HCHO reading']))): 
    temp_train = data['HCHO reading'][:train_size + t]
    model = SARIMAX(temp_train, order=(1, 1, 1), seasonal_order=(1, 0, 1, 12))  # SARIMA model with p=1,d=0,q=1 and seasonal order (P,D,Q,s) = (1,0,1,12)
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=1)  # Forecasting 10 steps ahead
    yhat_sarima.append(predictions[-1])  # Appending only the last value of the forecast

yhat_sarima = pd.Series(yhat_sarima, index=test.index)
sarima_mse = mean_squared_error(test['HCHO reading'], yhat_sarima)

# Print or store the results
print("SARIMA MSE:", sarima_mse)
# Out:
#   5%|████▍                                                                            | 20/366 [01:17<22:13,  3.85s/it]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[86], line 30
#      28 temp_train = data['HCHO reading'][:train_size + t]
#      29 model = SARIMAX(temp_train, order=(1, 1, 1), seasonal_order=(1, 0, 1, 12))  # SARIMA model with p=1,d=0,q=1 and seasonal order (P,D,Q,s) = (1,0,1,12)
# ---> 30 model_fit = model.fit()
#      31 predictions = model_fit.forecast(steps=1)  # Forecasting 10 steps ahead
#      32 yhat_sarima.append(predictions[-1])  # Appending only the last value of the forecast
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\base\optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\base\optimizer.py:659, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     656 elif approx_grad:
#     657     func = f
# --> 659 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     660                                  callback=callback, args=fargs,
#     661                                  bounds=bounds, disp=disp,
#     662                                  **extra_kwargs)
#     664 if full_output:
#     665     xopt, fopt, d = retvals
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187 callback = _wrap_callback(callback)
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_lbfgsb_py.py:365, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     359 task_str = task.tobytes()
#     360 if task_str.startswith(b'FG'):
#     361     # The minimization routine wants f and g at the current x.
#     362     # Note that interruptions due to maxfun are postponed
#     363     # until the completion of the current minimization iteration.
#     364     # Overwrite f and g:
# --> 365     f, g = func_and_grad(x)
#     366 elif task_str.startswith(b'NEW_X'):
#     367     # new iteration
#     368     n_iterations += 1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\base\model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\statespace\mlemodel.py:939, in MLEModel.loglike(self, params, *args, **kwargs)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 939 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     941 # Koopman, Shephard, and Doornik recommend maximizing the average
#     942 # likelihood to avoid scale issues, but the averaging is done
#     943 # automatically in the base model `fit` method
#     944 return loglike
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\statespace\kalman_filter.py:1001, in KalmanFilter.loglike(self, **kwargs)
#     985 r"""
#     986 Calculate the loglikelihood associated with the statespace model.
#     987
#    (...)
#     997     The joint loglikelihood.
#     998 """
#     999 kwargs.setdefault('conserve_memory',
#    1000                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# -> 1001 kfilter = self._filter(**kwargs)
#    1002 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1003                                 self.loglikelihood_burn)
#    1004 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\statespace\kalman_filter.py:921, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     918 kfilter = self._kalman_filters[prefix]
#     920 # Initialize the state
# --> 921 self._initialize_state(prefix=prefix, complex_step=complex_step)
#     923 # Run the filter
#     924 kfilter()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\statespace\representation.py:1058, in Representation._initialize_state(self, prefix, complex_step)
#    1056     if not self.initialization.initialized:
#    1057         raise RuntimeError('Initialization is incomplete.')
# -> 1058     self._statespaces[prefix].initialize(self.initialization,
#    1059                                          complex_step=complex_step)
#    1060 else:
#    1061     raise RuntimeError('Statespace model not initialized.')
#
# File statsmodels\\tsa\\statespace\\_representation.pyx:1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# File statsmodels\\tsa\\statespace\\_representation.pyx:1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# File statsmodels\\tsa\\statespace\\_initialization.pyx:288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# File statsmodels\\tsa\\statespace\\_initialization.pyx:406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# File statsmodels\\tsa\\statespace\\_tools.pyx:1626, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: Schur decomposition solver error.

# %%
# Plotting
plt.figure(figsize=(20, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_sarima, label='SARIMA Predictions', color='red')
plt.title('SARIMA Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True) 
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_sarima, label='SARIMA Predictions', color='red')
plt.title('SARIMA Model - Test Data vs. Predictions')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_sarima)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_sarima)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_sarima)

rmse = mean_squared_error(test['HCHO reading'], yhat_sarima, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_sarima)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_sarima)


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
