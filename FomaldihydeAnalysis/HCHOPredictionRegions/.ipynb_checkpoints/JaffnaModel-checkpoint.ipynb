# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, explained_variance_score

# %%
data = pd.read_csv("../NullValueHandled/jaffnaHandledNullValues.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                Next Date  HCHO reading
# Current Date
# 2019-01-01    2019-01-02      0.000058
# 2019-01-02    2019-01-03      0.000102
# 2019-01-03    2019-01-04      0.000039
# 2019-01-04    2019-01-05     -0.000002
# 2019-01-05    2019-01-06      0.000159

# %%
jaffna_data = data[["HCHO reading"]]
jaffna_data.head()
# Out:
#               HCHO reading
# Current Date
# 2019-01-01        0.000058
# 2019-01-02        0.000102
# 2019-01-03        0.000039
# 2019-01-04       -0.000002
# 2019-01-05        0.000159

# %%
jaffna_data.shape
# Out:
# (1826, 1)

# %%
X = jaffna_data.values

# %% [markdown]
# #### This looks like that Jaffna fomaldihyde rates have a seasonality

# %%
jaffna_data.plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='Current Date'>

# %% [markdown]
# #### Jaffna LSTM

# %%
data = pd.read_csv("../NullValueHandled/jaffnaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
print(data.head())
# Out:
#   Current Date  HCHO reading
# 0   2019-01-01      0.000058
# 1   2019-01-02      0.000102
# 2   2019-01-03      0.000039
# 3   2019-01-04     -0.000002
# 4   2019-01-05      0.000159

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# Assuming 'data' is your DataFrame and you've loaded it successfully

# Preprocess data
data['Current Date'] = pd.to_datetime(data['Current Date'])
data.sort_values(by='Current Date', inplace=True)
data.set_index('Current Date', inplace=True)

# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]

# Normalize the data
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# Define function to create sequences for RNN
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length, -1]) 
    return np.array(X), np.array(y)

sequence_length = 10

# Create sequences for training and testing data
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)

model = Sequential([
    Bidirectional(LSTM(units=200, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    Bidirectional(LSTM(units=150, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=50, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=25, return_sequences=True)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Bidirectional(LSTM(units=10)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

optimizer = RMSprop(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])


# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 90s 525ms/step - loss: 0.9517 - mean_squared_error: 0.9517 - val_loss: 0.9015 - val_mean_squared_error: 0.9015
# Epoch 2/20
# 37/37 [==============================] - 9s 229ms/step - loss: 0.9293 - mean_squared_error: 0.9293 - val_loss: 0.9341 - val_mean_squared_error: 0.9341
# Epoch 3/20
# 37/37 [==============================] - 8s 220ms/step - loss: 0.9414 - mean_squared_error: 0.9414 - val_loss: 0.8810 - val_mean_squared_error: 0.8810
# Epoch 4/20
# 37/37 [==============================] - 8s 214ms/step - loss: 0.9408 - mean_squared_error: 0.9408 - val_loss: 0.8984 - val_mean_squared_error: 0.8984
# Epoch 5/20
# 37/37 [==============================] - 7s 174ms/step - loss: 0.9343 - mean_squared_error: 0.9343 - val_loss: 0.8811 - val_mean_squared_error: 0.8811
# Epoch 6/20
# 37/37 [==============================] - 8s 230ms/step - loss: 0.9358 - mean_squared_error: 0.9358 - val_loss: 0.9126 - val_mean_squared_error: 0.9126
# Epoch 7/20
# 37/37 [==============================] - 7s 196ms/step - loss: 0.9415 - mean_squared_error: 0.9415 - val_loss: 0.8854 - val_mean_squared_error: 0.8854
# Epoch 8/20
# 37/37 [==============================] - 5s 133ms/step - loss: 0.9314 - mean_squared_error: 0.9314 - val_loss: 0.9331 - val_mean_squared_error: 0.9331
# Epoch 9/20
# 37/37 [==============================] - 11s 294ms/step - loss: 0.9418 - mean_squared_error: 0.9418 - val_loss: 0.8859 - val_mean_squared_error: 0.8859
# Epoch 10/20
# 37/37 [==============================] - 10s 277ms/step - loss: 0.9292 - mean_squared_error: 0.9292 - val_loss: 0.8771 - val_mean_squared_error: 0.8771
# Epoch 11/20
# 37/37 [==============================] - 9s 231ms/step - loss: 0.9404 - mean_squared_error: 0.9404 - val_loss: 0.9008 - val_mean_squared_error: 0.9008
# Epoch 12/20
# 37/37 [==============================] - 13s 347ms/step - loss: 0.9338 - mean_squared_error: 0.9338 - val_loss: 0.8958 - val_mean_squared_error: 0.8958
# Epoch 13/20
# 37/37 [==============================] - 10s 270ms/step - loss: 0.9239 - mean_squared_error: 0.9239 - val_loss: 0.9531 - val_mean_squared_error: 0.9531
# Epoch 14/20
# 37/37 [==============================] - 5s 135ms/step - loss: 0.9275 - mean_squared_error: 0.9275 - val_loss: 0.9464 - val_mean_squared_error: 0.9464
# Epoch 15/20
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9427 - mean_squared_error: 0.9427 - val_loss: 0.8826 - val_mean_squared_error: 0.8826
# Epoch 16/20
# 37/37 [==============================] - 6s 155ms/step - loss: 0.9300 - mean_squared_error: 0.9300 - val_loss: 0.9058 - val_mean_squared_error: 0.9058
# Epoch 17/20
# 37/37 [==============================] - 9s 241ms/step - loss: 0.9233 - mean_squared_error: 0.9233 - val_loss: 0.9234 - val_mean_squared_error: 0.9234
# Epoch 18/20
# 37/37 [==============================] - 8s 216ms/step - loss: 0.9313 - mean_squared_error: 0.9313 - val_loss: 0.8856 - val_mean_squared_error: 0.8856
# Epoch 19/20
# 37/37 [==============================] - 8s 228ms/step - loss: 0.9271 - mean_squared_error: 0.9271 - val_loss: 0.8841 - val_mean_squared_error: 0.8841
# Epoch 20/20
# 37/37 [==============================] - 8s 221ms/step - loss: 0.9271 - mean_squared_error: 0.9271 - val_loss: 0.8876 - val_mean_squared_error: 0.8876

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_test)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 11s 69ms/step
