# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, explained_variance_score

# %%
# Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("../NullValueHandled/MataraDeniyayaHandledNullValues.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                Next Date  HCHO reading
# Current Date
# 2019-01-01    2019-01-02      0.000006
# 2019-01-02    2019-01-03      0.000006
# 2019-01-03    2019-01-04      0.000236
# 2019-01-04    2019-01-05      0.000064
# 2019-01-05    2019-01-06      0.000053

# %%
matara_data = data[["HCHO reading"]]
matara_data.head()
# Out:
#               HCHO reading
# Current Date
# 2019-01-01        0.000006
# 2019-01-02        0.000006
# 2019-01-03        0.000236
# 2019-01-04        0.000064
# 2019-01-05        0.000053

# %%
matara_data.shape
# Out:
# (1826, 1)

# %%
X = matara_data.values

# %% [markdown]
# #### This looks like that Matara fomaldihyde rates have a small seasonality

# %%
matara_data.plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='Current Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_matara = adfuller(matara_data["HCHO reading"], autolag="AIC")

# %%
print("ADF value : ", test_matara[0])
print("P value: ", test_matara[1])
print("Num of Lags :", test_matara[2])
print("Num of Observations used for ADF Regression and Critical Calculation :", test_matara[3])
for key, val in test_matara[4].items():
    print("\t", key, ": ", val)
# Out:
# ADF value :  -6.235921108894503
# P value:  4.826071467176593e-08
# Num of Lags : 15
# Num of Observations used for ADF Regression and Critical Calculation : 1810
# 	 1% :  -3.433968010099092
# 	 5% :  -2.8631381499714745
# 	 10% :  -2.567620802173316

# %% [markdown]
# #### Auto correlation and correlation plot for Matara

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

pacf = plot_pacf(matara_data["HCHO reading"], lags=25)
acf = plot_acf(matara_data["HCHO reading"], lags=25)

# %% [markdown]
# #### There is a small seasanolity and stationarity in Matara Data

# %% [markdown]
# #### Matara with LSTM

# %%
data = pd.read_csv("../NullValueHandled/MataraDeniyayaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
print(data.head())
# Out:
#   Current Date  HCHO reading
# 0   2019-01-01      0.000006
# 1   2019-01-02      0.000006
# 2   2019-01-03      0.000236
# 3   2019-01-04      0.000064
# 4   2019-01-05      0.000053

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# Assuming 'data' is your DataFrame and you've loaded it successfully

# Preprocess data
data['Current Date'] = pd.to_datetime(data['Current Date'])
data.sort_values(by='Current Date', inplace=True)
data.set_index('Current Date', inplace=True)

# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]

# Normalize the data
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# Define function to create sequences for RNN
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length]) 
    return np.array(X), np.array(y) 

sequence_length = 5
# Create sequences for training and testing data
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)
 
model = Sequential([
    Bidirectional(LSTM(units=500, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    Bidirectional(LSTM(units=400, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=200, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=100, return_sequences=True)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Bidirectional(LSTM(units=10)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

optimizer = RMSprop(learning_rate=0.005) 
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 52s 301ms/step - loss: 1.1676 - mean_squared_error: 1.1676 - val_loss: 0.7684 - val_mean_squared_error: 0.7684
# Epoch 2/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0.9826 - mean_squared_error: 0.9826 - val_loss: 0.8025 - val_mean_squared_error: 0.8025
# Epoch 3/100
# 37/37 [==============================] - 5s 128ms/step - loss: 0.9519 - mean_squared_error: 0.9519 - val_loss: 0.8866 - val_mean_squared_error: 0.8866
# Epoch 4/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.9591 - mean_squared_error: 0.9591 - val_loss: 0.8255 - val_mean_squared_error: 0.8255
# Epoch 5/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9351 - mean_squared_error: 0.9351 - val_loss: 0.8442 - val_mean_squared_error: 0.8442
# Epoch 6/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9450 - mean_squared_error: 0.9450 - val_loss: 0.8032 - val_mean_squared_error: 0.8032
# Epoch 7/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9217 - mean_squared_error: 0.9217 - val_loss: 0.7822 - val_mean_squared_error: 0.7822
# Epoch 8/100
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9241 - mean_squared_error: 0.9241 - val_loss: 0.8273 - val_mean_squared_error: 0.8273
# Epoch 9/100
# 37/37 [==============================] - 5s 125ms/step - loss: 0.9300 - mean_squared_error: 0.9300 - val_loss: 0.7843 - val_mean_squared_error: 0.7843
# Epoch 10/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.9061 - mean_squared_error: 0.9061 - val_loss: 0.7859 - val_mean_squared_error: 0.7859
# Epoch 11/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.9245 - mean_squared_error: 0.9245 - val_loss: 0.8086 - val_mean_squared_error: 0.8086
# Epoch 12/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.9122 - mean_squared_error: 0.9122 - val_loss: 0.8165 - val_mean_squared_error: 0.8165
# Epoch 13/100
# 37/37 [==============================] - 4s 114ms/step - loss: 0.9042 - mean_squared_error: 0.9042 - val_loss: 0.8092 - val_mean_squared_error: 0.8092
# Epoch 14/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.9116 - mean_squared_error: 0.9116 - val_loss: 0.8133 - val_mean_squared_error: 0.8133
# Epoch 15/100
# 37/37 [==============================] - 4s 122ms/step - loss: 0.8944 - mean_squared_error: 0.8944 - val_loss: 0.8247 - val_mean_squared_error: 0.8247
# Epoch 16/100
# 37/37 [==============================] - 5s 136ms/step - loss: 0.8914 - mean_squared_error: 0.8914 - val_loss: 0.8226 - val_mean_squared_error: 0.8226
# Epoch 17/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.8979 - mean_squared_error: 0.8979 - val_loss: 0.8303 - val_mean_squared_error: 0.8303
# Epoch 18/100
# 37/37 [==============================] - 4s 120ms/step - loss: 0.8979 - mean_squared_error: 0.8979 - val_loss: 0.8349 - val_mean_squared_error: 0.8349
# Epoch 19/100
# 37/37 [==============================] - 5s 126ms/step - loss: 0.8892 - mean_squared_error: 0.8892 - val_loss: 0.8476 - val_mean_squared_error: 0.8476
# Epoch 20/100
# 37/37 [==============================] - 5s 142ms/step - loss: 0.9014 - mean_squared_error: 0.9014 - val_loss: 0.8234 - val_mean_squared_error: 0.8234
# Epoch 21/100
# 37/37 [==============================] - 5s 134ms/step - loss: 0.8910 - mean_squared_error: 0.8910 - val_loss: 0.8214 - val_mean_squared_error: 0.8214
# Epoch 22/100
# 37/37 [==============================] - 5s 131ms/step - loss: 0.8911 - mean_squared_error: 0.8911 - val_loss: 0.8310 - val_mean_squared_error: 0.8310
# Epoch 23/100
# 37/37 [==============================] - 5s 145ms/step - loss: 0.8868 - mean_squared_error: 0.8868 - val_loss: 0.8799 - val_mean_squared_error: 0.8799
# Epoch 24/100
# 37/37 [==============================] - 5s 127ms/step - loss: 0.8961 - mean_squared_error: 0.8961 - val_loss: 0.8195 - val_mean_squared_error: 0.8195
# Epoch 25/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.8968 - mean_squared_error: 0.8968 - val_loss: 0.8394 - val_mean_squared_error: 0.8394
# Epoch 26/100
# 37/37 [==============================] - 5s 128ms/step - loss: 0.8943 - mean_squared_error: 0.8943 - val_loss: 0.8273 - val_mean_squared_error: 0.8273
# Epoch 27/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0.8780 - mean_squared_error: 0.8780 - val_loss: 0.8262 - val_mean_squared_error: 0.8262
# Epoch 28/100
# 37/37 [==============================] - 5s 147ms/step - loss: 0.8750 - mean_squared_error: 0.8750 - val_loss: 0.8127 - val_mean_squared_error: 0.8127
# Epoch 29/100
# 37/37 [==============================] - 5s 134ms/step - loss: 0.8907 - mean_squared_error: 0.8907 - val_loss: 0.8552 - val_mean_squared_error: 0.8552
# Epoch 30/100
# 37/37 [==============================] - 5s 141ms/step - loss: 0.8782 - mean_squared_error: 0.8782 - val_loss: 0.8240 - val_mean_squared_error: 0.8240
# Epoch 31/100
# 37/37 [==============================] - 5s 131ms/step - loss: 0.8801 - mean_squared_error: 0.8801 - val_loss: 0.8404 - val_mean_squared_error: 0.8404
# Epoch 32/100
# 37/37 [==============================] - 5s 123ms/step - loss: 0.8630 - mean_squared_error: 0.8630 - val_loss: 0.8341 - val_mean_squared_error: 0.8341
# Epoch 33/100
# 37/37 [==============================] - 5s 132ms/step - loss: 0.8778 - mean_squared_error: 0.8778 - val_loss: 0.8213 - val_mean_squared_error: 0.8213
# Epoch 34/100
# 37/37 [==============================] - 5s 140ms/step - loss: 0.8468 - mean_squared_error: 0.8468 - val_loss: 0.8465 - val_mean_squared_error: 0.8465
# Epoch 35/100
# 37/37 [==============================] - 5s 137ms/step - loss: 0.8590 - mean_squared_error: 0.8590 - val_loss: 0.8348 - val_mean_squared_error: 0.8348
# Epoch 36/100
# 37/37 [==============================] - 5s 133ms/step - loss: 0.8549 - mean_squared_error: 0.8549 - val_loss: 0.8294 - val_mean_squared_error: 0.8294
# Epoch 37/100
# 37/37 [==============================] - 4s 115ms/step - loss: 0.8568 - mean_squared_error: 0.8568 - val_loss: 0.8377 - val_mean_squared_error: 0.8377
# Epoch 38/100
# 37/37 [==============================] - 5s 124ms/step - loss: 0.8586 - mean_squared_error: 0.8586 - val_loss: 0.8189 - val_mean_squared_error: 0.8189
# Epoch 39/100
# 37/37 [==============================] - 5s 130ms/step - loss: 0.8390 - mean_squared_error: 0.8390 - val_loss: 0.8746 - val_mean_squared_error: 0.8746
# Epoch 40/100
# 37/37 [==============================] - 5s 129ms/step - loss: 0
100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.4416 - mean_squared_error: 0.4416 - val_loss: 1.1887 - val_mean_squared_error: 1.1887
# Epoch 88/100
# 37/37 [==============================] - 6s 153ms/step - loss: 0.4502 - mean_squared_error: 0.4502 - val_loss: 1.1813 - val_mean_squared_error: 1.1813
# Epoch 89/100
# 37/37 [==============================] - 6s 154ms/step - loss: 0.4555 - mean_squared_error: 0.4555 - val_loss: 1.1400 - val_mean_squared_error: 1.1400
# Epoch 90/100
# 37/37 [==============================] - 6s 157ms/step - loss: 0.4412 - mean_squared_error: 0.4412 - val_loss: 1.1410 - val_mean_squared_error: 1.1410
# Epoch 91/100
# 37/37 [==============================] - 6s 152ms/step - loss: 0.4227 - mean_squared_error: 0.4227 - val_loss: 1.2403 - val_mean_squared_error: 1.2403
# Epoch 92/100
# 37/37 [==============================] - 6s 152ms/step - loss: 0.3953 - mean_squared_error: 0.3953 - val_loss: 1.1617 - val_mean_squared_error: 1.1617
# Epoch 93/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.4677 - mean_squared_error: 0.4677 - val_loss: 1.2016 - val_mean_squared_error: 1.2016
# Epoch 94/100
# 37/37 [==============================] - 6s 164ms/step - loss: 0.4275 - mean_squared_error: 0.4275 - val_loss: 1.3060 - val_mean_squared_error: 1.3060
# Epoch 95/100
# 37/37 [==============================] - 6s 163ms/step - loss: 0.4251 - mean_squared_error: 0.4251 - val_loss: 1.2541 - val_mean_squared_error: 1.2541
# Epoch 96/100
# 37/37 [==============================] - 6s 159ms/step - loss: 0.3661 - mean_squared_error: 0.3661 - val_loss: 1.3264 - val_mean_squared_error: 1.3264
# Epoch 97/100
# 37/37 [==============================] - 6s 159ms/step - loss: 0.3721 - mean_squared_error: 0.3721 - val_loss: 1.3139 - val_mean_squared_error: 1.3139
# Epoch 98/100
# 37/37 [==============================] - 6s 156ms/step - loss: 0.4123 - mean_squared_error: 0.4123 - val_loss: 1.1795 - val_mean_squared_error: 1.1795
# Epoch 99/100
# 37/37 [==============================] - 6s 170ms/step - loss: 0.3778 - mean_squared_error: 0.3778 - val_loss: 1.1741 - val_mean_squared_error: 1.1741
# Epoch 100/100
# 37/37 [==============================] - 6s 158ms/step - loss: 0.4052 - mean_squared_error: 0.4052 - val_loss: 1.1449 - val_mean_squared_error: 1.1449

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_test)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 15s 46ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_train)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 46/46 [==============================] - 1s 30ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled_test = model.predict(X_test)

# Inverse transform predictions and actual values to original scale for testing data
predictions_test = scaler.inverse_transform(predictions_scaled_test)
actual_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Predict values for training data
predictions_scaled_train = model.predict(X_train)

# Inverse transform predictions and actual values to original scale for training data
predictions_train = scaler.inverse_transform(predictions_scaled_train)
actual_train = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual_train, label='Actual (Train)', color='blue')
plt.plot(predictions_train, label='Predicted (Train)', color='orange')
plt.plot(len(predictions_train) + np.arange(len(predictions_test)), predictions_test, label='Predicted (Test)', color='red')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 27ms/step
# 46/46 [==============================] - 1s 31ms/step

# %%
y_test = actual
predicted_values = predictions.reshape(-1, 1)
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): 0.48869297695397773
# Mean Absolute Error (MAE): 2.950383432736348e-05
# Mean Squared Error (MSE): 1.8183295494729248e-09
# Root Mean Squared Error (RMSE): 4.264187553887522e-05
# Median Absolute Error: 1.9997588804808884e-05
# Explained Variance Score: 0.4936697144052463

# %% [markdown]
# #### FaceBook Prophet for Matara Deniyaya

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare your data
data = pd.read_csv("../NullValueHandled/NuwaraEliyaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data.rename(columns={'Current Date': 'ds', 'HCHO reading': 'y'}, inplace=True)
data['ds'] = pd.to_datetime(data['ds'])

# Define holidays
holidays = pd.DataFrame({
    'holiday': 'covid',
    'ds': pd.to_datetime(['2020-03-15', '2022-03-31']), 
    'lower_window': 0,
    'upper_window': 1,
})

train_size = int(0.80 * len(data)) 
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Initialize and fit the Prophet model with holidays
model = Prophet(holidays=holidays) 
model.fit(train_data)

# Create a dataframe for future dates predictions
future = model.make_future_dataframe(periods=365, 
                                    )

# Make predictions
forecast = model.predict(future)

# Plot the forecast
fig1 = model.plot(forecast)
ax = fig1.gca()

# Overlay actual data
ax.plot(train_data['ds'], train_data['y'], 'k.', label='Actual Data')

plt.show()
# Out:
# 23:45:44 - cmdstanpy - INFO - Chain [1] start processing
# 23:45:44 - cmdstanpy - INFO - Chain [1] done processing

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot actual data
sns.lineplot(data=train_data, x='ds', y='y', label='Actual Data', color='black', marker='o', linestyle='None')

# Plot yhat - forecast
sns.lineplot(data=forecast, x='ds', y='yhat', label='Forecast (yhat)', color='#6a0dad')  # Purple

# Plot yhat_upper
sns.lineplot(data=forecast, x='ds', y='yhat_upper', label='Forecast Upper Bound (yhat_upper)', color='#33a1ff')  # Teal

# Plot yhat_lower
sns.lineplot(data=forecast, x='ds', y='yhat_lower', label='Forecast Lower Bound (yhat_lower)', color='#00e6e6')  # Light Teal

plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='#d9b3ff', alpha=0.2, label='Confidence Interval')  # Light Purple

plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('HCHO Reading Forecast')

# Adjust legend
plt.legend()

plt.show()

# %%
# Plot the forecast components
fig2 = model.plot_components(forecast)

# %%
from tabulate import tabulate

y_test = test_data['y'][:-1]
predicted_values = forecast.loc[forecast['ds'].isin(test_data['ds']), 'yhat']  # Extract forecasted values for test period
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): -0.020566660431041717
# Mean Absolute Error (MAE): 4.072143774072999e-05
# Mean Squared Error (MSE): 3.421744828337752e-09
# Root Mean Squared Error (RMSE): 5.8495682134134925e-05
# Median Absolute Error: 2.8039746165212754e-05
# Explained Variance Score: -0.0157914092730993

# %% [markdown]
# #### Matara Multi Variate Model

# %%
data = pd.read_csv("../AnalysedFinalData/mataraData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Current Date          1826 non-null   object
#  1   HCHO reading          1826 non-null   float64
#  2   Region                1826 non-null   object
#  3   LATITUDE              1826 non-null   float64
#  4   LONGITUDE             1826 non-null   float64
#  5   ELEVATION             1826 non-null   int64
#  6   PRCP                  1826 non-null   float64
#  7   TAVG                  1826 non-null   float64
#  8   TMAX                  1826 non-null   float64
#  9   TMIN                  1826 non-null   float64
#  10  Population            1826 non-null   int64
#  11  Area_sq_km            1826 non-null   int64
#  12  population_density    1826 non-null   float64
#  13  Proximity(km)         1826 non-null   int64
#  14  carbon_monoxide       1826 non-null   float64
#  15  nitogen_dioxide       1826 non-null   float64
#  16  ozone                 1826 non-null   float64
#  17  new_covid_patients    1826 non-null   int64
#  18  total_covid_patients  1826 non-null   int64
#  19  lockdown_status       1826 non-null   object
#  20  covid_range_status    1826 non-null   object
# dtypes: float64(11), int64(6), object(4)
# memory usage: 299.7+ KB

# %%
data.head()
# Out:
#   Current Date  HCHO reading            Region  LATITUDE  LONGITUDE  \
# 0   2019-01-01      0.000006  Deniyaya, Matara      6.34      80.55
# 1   2019-01-02      0.000006  Deniyaya, Matara      6.34      80.55
# 2   2019-01-03      0.000236  Deniyaya, Matara      6.34      80.55
# 3   2019-01-04      0.000064  Deniyaya, Matara      6.34      80.55
# 4   2019-01-05      0.000053  Deniyaya, Matara      6.34      80.55
#
#    ELEVATION  PRCP    TAVG    TMAX    TMIN  Population  Area_sq_km  \
# 0          7  0.27  79.340  84.398  75.560      863000        1283
# 1          7  0.06  78.440  83.318  74.516      863000        1283
# 2          7  0.03  78.728  84.074  74.264      863000        1283
# 3          7  0.02  78.368  83.642  73.688      863000        1283
# 4          7  0.09  79.070  85.118  73.670      863000        1283
#
#    population_density  Proximity(km)  carbon_monoxide  nitogen_dioxide  \
# 0              672.64              0         0.034421         0.000013
# 1              672.64              0         0.035665         0.000017
# 2              672.64              0         0.033910         0.000017
# 3              672.64              0         0.038113         0.000019
# 4              672.64              0         0.033754         0.000019
#
#       ozone  new_covid_patients  total_covid_patients lockdown_status  \
# 0  0.115856                   0                     0          Before
# 1  0.115856                   0                     0          Before
# 2  0.115856                   0                     0          Before
# 3  0.115856                   0                     0          Before
# 4  0.115856                   0                     0          Before
#
#   covid_range_status
# 0             Before
# 1             Before
# 2             Before
# 3             Before
# 4             Before

# %% [markdown]
# #### remove constant data

# %%
data.columns
# Out:
# Index(['Current Date', 'HCHO reading', 'Region', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 'Area_sq_km',
#        'population_density', 'Proximity(km)', 'carbon_monoxide',
#        'nitogen_dioxide', 'ozone', 'new_covid_patients',
#        'total_covid_patients', 'lockdown_status', 'covid_range_status'],
#       dtype='object')

# %%
data.drop(columns=['Region', 'LATITUDE', 'LONGITUDE',
       'ELEVATION','Area_sq_km', 'Proximity(km)'], inplace=True)

# %%
data.head()
# Out:
#   Current Date  HCHO reading  PRCP    TAVG    TMAX    TMIN  Population  \
# 0   2019-01-01      0.000006  0.27  79.340  84.398  75.560      863000
# 1   2019-01-02      0.000006  0.06  78.440  83.318  74.516      863000
# 2   2019-01-03      0.000236  0.03  78.728  84.074  74.264      863000
# 3   2019-01-04      0.000064  0.02  78.368  83.642  73.688      863000
# 4   2019-01-05      0.000053  0.09  79.070  85.118  73.670      863000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              672.64         0.034421         0.000013  0.115856
# 1              672.64         0.035665         0.000017  0.115856
# 2              672.64         0.033910         0.000017  0.115856
# 3              672.64         0.038113         0.000019  0.115856
# 4              672.64         0.033754         0.000019  0.115856
#
#    new_covid_patients  total_covid_patients lockdown_status covid_range_status
# 0                   0                     0          Before             Before
# 1                   0                     0          Before             Before
# 2                   0                     0          Before             Before
# 3                   0                     0          Before             Before
# 4                   0                     0          Before             Before

# %% [markdown]
# #### Encode Categorical data

# %%
from sklearn.preprocessing import LabelEncoder
 
dates = data["Current Date"]

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate through each column in the DataFrame
for column in data.columns:
    # Check if the column is of categorical type
    if data[column].dtype == 'object':
        # Fit label encoder and transform values
        data[column] = label_encoder.fit_transform(data[column])

# %%
data["Current Date"] = dates
data.head()
# Out:
#   Current Date  HCHO reading  PRCP    TAVG    TMAX    TMIN  Population  \
# 0   2019-01-01      0.000006  0.27  79.340  84.398  75.560      863000
# 1   2019-01-02      0.000006  0.06  78.440  83.318  74.516      863000
# 2   2019-01-03      0.000236  0.03  78.728  84.074  74.264      863000
# 3   2019-01-04      0.000064  0.02  78.368  83.642  73.688      863000
# 4   2019-01-05      0.000053  0.09  79.070  85.118  73.670      863000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              672.64         0.034421         0.000013  0.115856
# 1              672.64         0.035665         0.000017  0.115856
# 2              672.64         0.033910         0.000017  0.115856
# 3              672.64         0.038113         0.000019  0.115856
# 4              672.64         0.033754         0.000019  0.115856
#
#    new_covid_patients  total_covid_patients  lockdown_status  \
# 0                   0                     0                1
# 1                   0                     0                1
# 2                   0                     0                1
# 3                   0                     0                1
# 4                   0                     0                1
#
#    covid_range_status
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# #### Check correlations

# %%
corr = data.corr(numeric_only=True)["HCHO reading"]
corr = pd.DataFrame(corr)
corr
# Out:
#                       HCHO reading
# HCHO reading              1.000000
# PRCP                     -0.033231
# TAVG                      0.082761
# TMAX                      0.177749
# TMIN                     -0.063090
# Population               -0.053554
# population_density       -0.053554
# carbon_monoxide           0.248222
# nitogen_dioxide           0.155423
# ozone                    -0.089257
# new_covid_patients       -0.124086
# total_covid_patients     -0.055990
# lockdown_status          -0.032355
# covid_range_status        0.012161

# %%
corr.to_csv("../OtherData/MataraCorrelationData.csv")

# %%
data.shape
# Out:
# (1826, 15)

# %% [markdown]
# #### remove covid range status

# %%
data.drop(columns=["covid_range_status"], inplace=True)

# %% [markdown]
# #### Devide X and Y

# %%
X = data.drop(columns=["HCHO reading"])
y = data["HCHO reading"]

# %%
X.head()
# Out:
#   Current Date  PRCP    TAVG    TMAX    TMIN  Population  population_density  \
# 0   2019-01-01  0.27  79.340  84.398  75.560      863000              672.64
# 1   2019-01-02  0.06  78.440  83.318  74.516      863000              672.64
# 2   2019-01-03  0.03  78.728  84.074  74.264      863000              672.64
# 3   2019-01-04  0.02  78.368  83.642  73.688      863000              672.64
# 4   2019-01-05  0.09  79.070  85.118  73.670      863000              672.64
#
#    carbon_monoxide  nitogen_dioxide     ozone  new_covid_patients  \
# 0         0.034421         0.000013  0.115856                   0
# 1         0.035665         0.000017  0.115856                   0
# 2         0.033910         0.000017  0.115856                   0
# 3         0.038113         0.000019  0.115856                   0
# 4         0.033754         0.000019  0.115856                   0
#
#    total_covid_patients  lockdown_status
# 0                     0                1
# 1                     0                1
# 2                     0                1
# 3                     0                1
# 4                     0                1

# %% [markdown]
# #### Select features based on Correlations

# %%
data.corr(numeric_only=True)["HCHO reading"]
# Out:
# HCHO reading            1.000000
# PRCP                   -0.033231
# TAVG                    0.082761
# TMAX                    0.177749
# TMIN                   -0.063090
# Population             -0.053554
# population_density     -0.053554
# carbon_monoxide         0.248222
# nitogen_dioxide         0.155423
# ozone                  -0.089257
# new_covid_patients     -0.124086
# total_covid_patients   -0.055990
# lockdown_status        -0.032355
# Name: HCHO reading, dtype: float64

# %%
X = X[["Current Date", "carbon_monoxide", "nitogen_dioxide", "new_covid_patients", "TMAX"]]
X.head()
# Out:
#   Current Date  carbon_monoxide  nitogen_dioxide  new_covid_patients    TMAX
# 0   2019-01-01         0.034421         0.000013                   0  84.398
# 1   2019-01-02         0.035665         0.000017                   0  83.318
# 2   2019-01-03         0.033910         0.000017                   0  84.074
# 3   2019-01-04         0.038113         0.000019                   0  83.642
# 4   2019-01-05         0.033754         0.000019                   0  85.118

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Current Date        1826 non-null   object
#  1   carbon_monoxide     1826 non-null   float64
#  2   nitogen_dioxide     1826 non-null   float64
#  3   new_covid_patients  1826 non-null   int64
#  4   TMAX                1826 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 71.5+ KB

# %% [markdown]
# #### Standardize, variable data

# %%
from sklearn.preprocessing import StandardScaler
# Select columns of interest
selected_columns = ["carbon_monoxide", "nitogen_dioxide", "TMAX"]

# Convert "Current Date" to datetime format
data["Current Date"] = pd.to_datetime(data["Current Date"])

# Separate the "Current Date" column
current_date = data["Current Date"]

# Select only the columns you're interested in for standardization
X = X[selected_columns]

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the scaler on the data
X_scaled = scaler.fit_transform(X)

# Convert the scaled data back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=selected_columns)

# Concatenate "Current Date" column with the scaled data
X = pd.concat([current_date, X_scaled_df], axis=1)

X.set_index("Current Date", inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2019-01-01 to 2023-12-31
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carbon_monoxide  1826 non-null   float64
#  1   nitogen_dioxide  1826 non-null   float64
#  2   TMAX             1826 non-null   float64
# dtypes: float64(3)
# memory usage: 57.1 KB

# %% [markdown]
# ##### Standardize target variable

# %%
y = data['HCHO reading']

y.head()
# Out:
# 0    0.000006
# 1    0.000006
# 2    0.000236
# 3    0.000064
# 4    0.000053
# Name: HCHO reading, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_y = MinMaxScaler()
y_scaled = np.array(scaler_y.fit_transform(y.values.reshape(-1, 1)), ndmin=1)

# %%
X_scaled = X

# %%
plt.figure(figsize=(20, 8))
plt.plot(scaler_y.inverse_transform(y_scaled))

# %%
print(X_scaled.head())
# Out:
#               carbon_monoxide  nitogen_dioxide      TMAX
# Current Date
# 2019-01-01           0.720730         0.019158  0.202610
# 2019-01-02           0.925758         0.535860 -0.450654
# 2019-01-03           0.636407         0.541221  0.006630
# 2019-01-04           1.329390         0.843722 -0.254675
# 2019-01-05           0.610689         0.827827  0.638119

# %% [markdown]
# #### Apply multivariate time series model

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L1
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import MeanAbsoluteError


# Now, split the data into training and testing sets
split_ratio = 0.8
split_index = int(len(X_scaled) * split_ratio)

X_train, X_test = X_scaled[:split_index], X_scaled[split_index:]
y_train, y_test = y_scaled[:split_index], y_scaled[split_index:]


X_train = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = np.array(X_test).reshape((X_test.shape[0], 1, X_test.shape[1]))

model = Sequential([
    Bidirectional(LSTM(units=400, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2), # Adding a Dropout layer for regularization
    Bidirectional(LSTM(units=10, activation="tanh")),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

# Compilation of the model
optimizer = Adam(learning_rate=0.008)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

# Train the model with validation data
history = model.fit(X_train, y_train, epochs=150, batch_size=128, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 12/12 [==============================] - 14s 269ms/step - loss: 0.0891 - mean_squared_error: 0.0891 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 2/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 3/150
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 4/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 5/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 6/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 7/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 8/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 9/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 10/150
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 11/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 12/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 13/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 14/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 15/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 16/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 17/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 18/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 19/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 20/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 21/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 22/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 23/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 24/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 25/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 26/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 27/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 28/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 29/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 30/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 31/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 32/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 33/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 34/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 35/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 36/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 37/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 38/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 39/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 40/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 41/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 42/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 43/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 44/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 45/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 46/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 47/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 48/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 49/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 50/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 51/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 52/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 53/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 54/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 55/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 56/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 57/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 58/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 59/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 60/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 61/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 62/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 63/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 64/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 65/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 66/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 67/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 68/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 69/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 70/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 71/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 72/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 73/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 74/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 75/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 76/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 77/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 78/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 79/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 80/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 81/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 82/150
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 83/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 84/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 85/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 86/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 87/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 88/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 89/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 90/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 91/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 92/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 93/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 94/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 95/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 96/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 97/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 98/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 99/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 100/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 101/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 102/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 103/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 104/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 105/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 106/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 107/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 108/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 109/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 110/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 111/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 112/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 113/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 114/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 115/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 116/150
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 117/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 118/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 119/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 120/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 121/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 122/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 123/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 124/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 125/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 126/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 127/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 128/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 129/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 130/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 131/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 132/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 133/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 134/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 135/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 136/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 137/150
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 138/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 139/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 140/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 141/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 142/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 143/150
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 144/150
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 145/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 146/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 147/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 148/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 149/150
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 150/150
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0188 - val_mean_squared_error: 0.0188

# %%
# Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")

# Make predictions
predictions = model.predict(X_test)

# Optionally, you can inverse transform the predictions to get them back to the original scale
predictions_inv = scaler_y.inverse_transform(predictions)
actual = scaler_y.inverse_transform(y_test.reshape(-1, 1))
import matplotlib.pyplot as plt

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions_inv, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_squared_error: 0.0188
# Test Loss: [0.018819481134414673, 0.018819481134414673]
# 12/12 [==============================] - 2s 4ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled_test = model.predict(X_test)

# Inverse transform predictions and actual values to original scale for testing data
predictions_test = scaler_y.inverse_transform(predictions)
actual_test = scaler_y.inverse_transform(y_test.reshape(-1, 1))

# Predict values for training data
predictions_scaled_train = model.predict(X_train)

# Inverse transform predictions and actual values to original scale for training data
predictions_train = scaler_y.inverse_transform(predictions_scaled_train)
actual_train = scaler_y.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(20, 8))
plt.plot(data["HCHO reading"], label='Actual (Train)', color='blue')
plt.plot(predictions_train, label='Predicted (Train)', color='orange')
plt.plot(len(predictions_train) + np.arange(len(predictions_test)), predictions_test, label='Predicted (Test)', color='red')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 5ms/step
# 46/46 [==============================] - 0s 4ms/step

# %%
r2 = (r2_score(actual_test, predictions_test))
mae = mean_absolute_error(actual_test, predictions_test)
mse = mean_squared_error(actual_test, predictions_test) 
rmse = mean_squared_error(actual_test, predictions_test, squared=False)
median_absolute = median_absolute_error(actual_test,predictions_test)
explained_variance = explained_variance_score(actual_test, predictions_test)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): 0.07409274218454431
# Mean Absolute Error (MAE): 4.3342009793802596e-05
# Mean Squared Error (MSE): 3.6816369588670784e-09
# Root Mean Squared Error (RMSE): 6.067649428623145e-05
# Median Absolute Error: 2.9342448896164392e-05
# Explained Variance Score: 0.07626445176401742

# %% [markdown]
# ### Single Variate Time Series Models

# %%
from statsmodels.tsa.arima.model import ARIMA
import pandas as pd
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/mataraData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

data_dict = {
     'carbon_monoxide': data["carbon_monoxide"],
    'nitrogen_dioxide': data["nitogen_dioxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')


# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# ARIMA example
yhat_ar = [] 

for t in tqdm(range(len(test['HCHO reading']))):
    temp_train = data['HCHO reading'][:train_size + t]
    model = ARIMA(temp_train, order=(3, 0, 0))  # AR model with p=1, d=0, q=0 (since it's AR)
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=1)[0]  # Forecasting 1 step ahead
    yhat_ar.append(predictions)

yhat_ar = pd.Series(yhat_ar, index=test.index)
ar_mse = mean_squared_error(test['HCHO reading'], yhat_ar)

# Print or store the results
print("ARIMA MSE:", ar_mse)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 366/366 [07:02<00:00,  1.15s/it]
# ARIMA MSE: 3.4941697744713647e-09

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_ar, label='ARIMA Predictions', color='red')
plt.title('AR Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(20, 8))
plt.plot(train.index, train['HCHO reading'], label='Train')
plt.plot(test.index, test['HCHO reading'], label='Test')
plt.plot(test.index, yhat_ar, label='Predicted')

plt.title('AR Forecast')
plt.xlabel('Date')
plt.ylabel('HCHO reading')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_ar)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_ar)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_ar) 

rmse = mean_squared_error(test['HCHO reading'], yhat_ar, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_ar)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_ar) 


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# Mean Absolute Error (MAE): 4.080773377545222e-05
# Mean Squared Error (MSE): 3.4941697744713647e-09
# R-squared (R2) Score: 0.12123949472247875
# Root Mean Squared Error (RMSE): 5.911150289471047e-05
# Median Absolute Error: 2.5536695995584585e-05
# Explained Variance Score: 0.12189852861080264

# %% [markdown]
# ####  ARIMA model

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/mataraData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
     'carbon_monoxide': data["carbon_monoxide"],
    'nitrogen_dioxide': data["nitogen_dioxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# SARIMA example using auto_arima
model = auto_arima(train['HCHO reading'], exogenous=train[['carbon_monoxide', 'nitrogen_dioxide', 'TMAX']],
                   seasonal=True, m=12,  # assuming monthly seasonality
                   trace=True)  # to display the model selection process
model_fit = model.fit(train['HCHO reading'], exogenous=train[['carbon_monoxide', 'nitrogen_dioxide', 'TMAX']])

# Forecasting
forecast = model_fit.predict(n_periods=len(test), exogenous=test[['carbon_monoxide', 'nitrogen_dioxide', 'TMAX']])

# Calculating MSE
sarima_mse = mean_squared_error(test['HCHO reading'], forecast)

# Print or store the results
print("SARIMA MSE:", sarima_mse)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=-24189.520, Time=5.92 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-24250.892, Time=0.24 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-23858.127, Time=3.73 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-24315.645, Time=4.13 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-22564.391, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=-24287.489, Time=0.87 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=-24173.536, Time=5.40 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=-24314.367, Time=10.96 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=-23867.369, Time=2.28 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=22.25 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=-24283.280, Time=2.98 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=-24363.455, Time=5.54 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=-24349.558, Time=1.08 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=-24313.129, Time=5.97 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=-24361.425, Time=11.62 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=-23885.658, Time=4.71 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=16.61 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=-24348.133, Time=5.18 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=-24348.571, Time=4.94 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=-24354.742, Time=4.80 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=-24320.262, Time=4.84 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=-24364.203, Time=5.84 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=-24357.898, Time=1.34 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=-24016.217, Time=28.12 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=-24362.084, Time=13.66 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=-23842.082, Time=3.24 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=14.31 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=-24382.994, Time=3.53 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=-24380.808, Time=0.54 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=-24111.669, Time=36.07 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=-24378.643, Time=6.09 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=-23846.364, Time=5.02 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=13.44 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=-24394.673, Time=4.01 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=-24395.424, Time=0.60 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=-23848.743, Time=4.91 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=-24291.602, Time=10.21 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=-24413.030, Time=0.85 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=-23866.146, Time=9.10 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=-24409.329, Time=3.18 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=-24356.912, Time=23.33 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=-24409.884, Time=0.93 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=-24391.715, Time=0.69 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : AIC=-24306.196, Time=0.97 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12] intercept
# Total fit time: 314.245 seconds
# SARIMA MSE: 3.987746138127689e-09

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/mataraData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
     'carbon_monoxide': data["carbon_monoxide"],
    'nitrogen_dioxide': data["nitogen_dioxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# ARIMA example
yhat_arma = []

for t in tqdm(range(len(test['HCHO reading']))):
    temp_train = data['HCHO reading'][:train_size + t]
    model = ARIMA(temp_train, order=(5, 0, 0))  # ARMA model with p=1,d=0,  q=1
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=10)[0]
    yhat_arma.append(predictions)

yhat_arma = pd.Series(yhat_arma, index=test.index)
arma_mse = mean_squared_error(test['HCHO reading'], yhat_arma)

# Print or store the results
print("ARIMA MSE:", arma_mse)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 366/366 [05:48<00:00,  1.05it/s]
# ARIMA MSE: 3.411311282155624e-09

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_arma, label='ARIMA Predictions', color='red')
plt.title('ARIMA Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_arma, label='ARIMA Predictions', color='red')
plt.title('ARIMA Model - Test Data vs. Predictions')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_arma)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_arma)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_arma)

rmse = mean_squared_error(test['HCHO reading'], yhat_arma, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_arma)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_arma)


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# Mean Absolute Error (MAE): 3.931678797789383e-05
# Mean Squared Error (MSE): 3.411311282155624e-09
# R-squared (R2) Score: 0.1420778555559702
# Root Mean Squared Error (RMSE): 5.840643185605182e-05
# Median Absolute Error: 2.292069853534717e-05
# Explained Variance Score: 0.14241294604265797

# %% [markdown]
# #### Single variate SARIMA model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Assuming 'data' is your DataFrame that includes the HCHO readings
# Let's mock the DataFrame here
data = pd.read_csv("../AnalysedFinalData/mataraData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data_dict = {
    'carbon_monoxide': data["carbon_monoxide"],
    'nitrogen_dioxide': data["nitogen_dioxide"],
    'TMAX': data["TMAX"],
    'HCHO reading': data["HCHO reading"]
}
data = pd.DataFrame(data_dict)
data.index = pd.date_range(start='2019-01-01', periods=len(data), freq='D')

# Splitting the data into training and test sets
train_size = int(len(data) * 0.8)  # 80% of data for training, 20% for testing
train = data.iloc[:train_size]
test = data.iloc[train_size:]

# SARIMA example
yhat_sarima = []

for t in tqdm(range(len(test['HCHO reading']))):
    temp_train = data['HCHO reading'][:train_size + t]
    model = SARIMAX(temp_train, order=(5, 0, 0), seasonal_order=(0, 0, 0, 12))  # SARIMA model with p=1,d=0,q=1 and seasonal order (P,D,Q,s) = (1,0,1,12)
    model_fit = model.fit()
    predictions = model_fit.forecast(steps=1)  # Forecasting 10 steps ahead
    yhat_sarima.append(predictions[-1])  # Appending only the last value of the forecast

yhat_sarima = pd.Series(yhat_sarima, index=test.index)
sarima_mse = mean_squared_error(test['HCHO reading'], yhat_sarima)

# Print or store the results
print("SARIMA MSE:", sarima_mse)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 366/366 [08:35<00:00,  1.41s/it]
# SARIMA MSE: 3.6255613374741364e-09

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train.index, train['HCHO reading'], label='Training data')
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_sarima, label='SARIMA Predictions', color='red')
plt.title('SARIMA Model - Actual vs. Predicted HCHO Readings')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True) 
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['HCHO reading'], label='Test data')
plt.plot(test.index, yhat_sarima, label='SARIMA Predictions', color='red')
plt.title('SARIMA Model - Test Data vs. Predictions')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate MAE
mae = mean_absolute_error(test['HCHO reading'], yhat_sarima)

# Calculate MSE
mse = mean_squared_error(test['HCHO reading'], yhat_sarima)

# Calculate R2 score
r2 = r2_score(test['HCHO reading'], yhat_sarima)

rmse = mean_squared_error(test['HCHO reading'], yhat_sarima, squared=False)

median_absolute = median_absolute_error(test['HCHO reading'],yhat_sarima)

explained_variance = explained_variance_score(test['HCHO reading'], yhat_sarima)


# Print the results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) Score:", r2)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# Mean Absolute Error (MAE): 4.020017735812323e-05
# Mean Squared Error (MSE): 3.6255613374741364e-09
# R-squared (R2) Score: 0.08819538875570809
# Root Mean Squared Error (RMSE): 6.021263436749912e-05
# Median Absolute Error: 2.5965879680077106e-05
# Explained Variance Score: 0.0967686385312263
