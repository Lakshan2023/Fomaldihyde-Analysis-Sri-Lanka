# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, explained_variance_score

# %%
# Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("../NullValueHandled/NuwaraEliyaHandledNullValues.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                Next Date  HCHO reading
# Current Date
# 2019-01-01    2019-01-02      0.000191
# 2019-01-02    2019-01-03      0.000191
# 2019-01-03    2019-01-04      0.000191
# 2019-01-04    2019-01-05      0.000051
# 2019-01-05    2019-01-06      0.000065

# %%
NuwaraEliya_data = data[["HCHO reading"]]
NuwaraEliya_data.head()
# Out:
#               HCHO reading
# Current Date
# 2019-01-01        0.000191
# 2019-01-02        0.000191
# 2019-01-03        0.000191
# 2019-01-04        0.000051
# 2019-01-05        0.000065

# %%
NuwaraEliya_data.shape
# Out:
# (1826, 1)

# %%
X = NuwaraEliya_data.values

# %% [markdown]
# #### This looks like that Nuwara Eliya fomaldihyde rates have a seasonality

# %%
NuwaraEliya_data.plot(figsize=(20, 6))
# Out:
# <Axes: xlabel='Current Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_nuwaraeliya = adfuller(NuwaraEliya_data["HCHO reading"], autolag="AIC")

# %%
print("ADF value : ", test_nuwaraeliya[0])
print("P value: ", test_nuwaraeliya[1])
print("Num of Lags :", test_nuwaraeliya[2])
print("Num of Observations used for ADF Regression and Critical Calculation :", test_nuwaraeliya[3])
for key, val in test_nuwaraeliya[4].items():
    print("\t", key, ": ", val)
# Out:
# ADF value :  -7.806557397054526
# P value:  7.255531724210168e-12
# Num of Lags : 10
# Num of Observations used for ADF Regression and Critical Calculation : 1815
# 	 1% :  -3.4339580289794225
# 	 5% :  -2.8631337437669275
# 	 10% :  -2.567618456010139

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

pacf = plot_pacf(NuwaraEliya_data["HCHO reading"], lags=25)
acf = plot_acf(NuwaraEliya_data["HCHO reading"], lags=25)

# %% [markdown]
# #### It shows there is a small seasanolity in the nuwara eliya dataset,however the partial Auto correlation plot shows there is a stationarity as well.

# %%
train=X[:1460]
test=X[1460:]

# %%
train[:5]
# Out:
# array([[1.90829389e-04],
#        [1.90829389e-04],
#        [1.90829389e-04],
#        [5.09762592e-05],
#        [6.45664550e-05]])

# %% [markdown]
# #### Check with Auto Regression Model

# %%
# Import necessary libraries
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.api import AutoReg

# Assuming train is already defined as a numpy array

# Define the scaler
scaler = MinMaxScaler()

# Fit the scaler to the training data and transform it
scaler.fit(train.reshape(-1, 1))
train_normalized = scaler.transform(train.reshape(-1, 1))

# Convert the normalized data back to a numpy array
train_normalized = train_normalized.flatten()

# Train the AutoReg model
model = AutoReg(train_normalized, lags=25).fit()

# %%
# Make predictions using the trained model
predicted_normalized = model.predict(start=len(train_normalized), end=len(train_normalized) + len(test) - 1, dynamic=False)

# Inverse transform the predicted values to the original scale
predicted_values = scaler.inverse_transform(predicted_normalized.reshape(-1, 1)).flatten()

# Create a DataFrame for predicted values
predicted_df = pd.DataFrame(predicted_values, columns=['predicted'])

test = pd.DataFrame(test)
# Set the index of the predicted DataFrame to match the test data index
predicted_df.index = test.index

# Add the actual values from the test set to the DataFrame
predicted_df['actual'] = test

# Display the DataFrame with predicted and actual values
print(predicted_df.head())
# Out:
#    predicted    actual
# 0   0.000052 -0.000004
# 1   0.000054  0.000121
# 2   0.000072  0.000063
# 3   0.000057  0.000046
# 4   0.000057  0.000051

# %%
from matplotlib import pyplot

pyplot.plot(test, color="orange", label='Actual Values')
pyplot.plot(predicted_values, label='Predicted Values')
pyplot.legend()

# %% [markdown]
# #### There is a fluctuation of the values, but it cannot findout the pattern properly

# %%
from tabulate import tabulate
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, explained_variance_score

# Assuming you have your test and predicted values stored in 'test' and 'predicted_values' variables

# Calculate the metrics
r_squared = r2_score(test, predicted_values)
mae = mean_absolute_error(test, predicted_values)
mse = mean_squared_error(test, predicted_values)
rmse = mean_squared_error(test, predicted_values, squared=False)
median_absolute = median_absolute_error(test, predicted_values)
explained_variance = explained_variance_score(test, predicted_values)

table_headers = ["Metric", "Value"]
table_data = {
    "R-squared (Coefficient of Determination)": "{:.12f}".format(r_squared),
    "Mean Absolute Error (MAE)": "{:.12f}".format(mae),
    "Mean Squared Error (MSE)": "{:.12f}".format(mse),
    "Root Mean Squared Error (RMSE)": "{:.12f}".format(rmse),
    "Median Absolute Error": "{:.12f}".format(median_absolute),
    "Explained Variance Score": "{:.12f}".format(explained_variance)
}

# Create DataFrame
df = pd.DataFrame(table_data.items(), columns=table_headers)

df
# Out:
#                                      Metric            Value
# 0  R-squared (Coefficient of Determination)  -0.002890420843
# 1                 Mean Absolute Error (MAE)   0.000041806513
# 2                  Mean Squared Error (MSE)   0.000000003358
# 3            Root Mean Squared Error (RMSE)   0.000057947750
# 4                     Median Absolute Error   0.000028070465
# 5                  Explained Variance Score  -0.000492248450

# %% [markdown]
# #### Nuwara Eliya with LSTM

# %%
data = pd.read_csv("../NullValueHandled/NuwaraEliyaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
print(data.head())
# Out:
#   Current Date  HCHO reading
# 0   2019-01-01      0.000191
# 1   2019-01-02      0.000191
# 2   2019-01-03      0.000191
# 3   2019-01-04      0.000051
# 4   2019-01-05      0.000065

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# Assuming 'data' is your DataFrame and you've loaded it successfully

# Preprocess data
data['Current Date'] = pd.to_datetime(data['Current Date'])
data.sort_values(by='Current Date', inplace=True)
data.set_index('Current Date', inplace=True)

# Split data into train and test sets
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]

# Normalize the data
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# Define function to create sequences for RNN
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length)])
        y.append(data[i + seq_length]) 
    return np.array(X), np.array(y) 

sequence_length = 5
# Create sequences for training and testing data
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)
 
model = Sequential([
    Bidirectional(LSTM(units=500, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    Bidirectional(LSTM(units=400, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=200, return_sequences=True)),
    Dropout(0.2),
    Bidirectional(LSTM(units=100, return_sequences=True)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Bidirectional(LSTM(units=10)),  # New Bidirectional LSTM layer
    Dropout(0.2),  # Adding a Dropout layer for regularization
    Dense(units=1)
])

optimizer = RMSprop(learning_rate=0.005) 
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

# Train the model
history = model.fit(X_train, y_train, epochs=130, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/130
# WARNING:tensorflow:From C:\Users\laksh\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\laksh\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 37/37 [==============================] - 33s 269ms/step - loss: 1.1055 - mean_squared_error: 1.1055 - val_loss: 0.6485 - val_mean_squared_error: 0.6485
# Epoch 2/130
# 37/37 [==============================] - 5s 141ms/step - loss: 1.0822 - mean_squared_error: 1.0822 - val_loss: 0.7846 - val_mean_squared_error: 0.7846
# Epoch 3/130
# 37/37 [==============================] - 4s 115ms/step - loss: 1.0741 - mean_squared_error: 1.0741 - val_loss: 0.5931 - val_mean_squared_error: 0.5931
# Epoch 4/130
# 37/37 [==============================] - 5s 124ms/step - loss: 1.0606 - mean_squared_error: 1.0606 - val_loss: 0.5878 - val_mean_squared_error: 0.5878
# Epoch 5/130
# 37/37 [==============================] - 4s 118ms/step - loss: 1.0401 - mean_squared_error: 1.0401 - val_loss: 0.5863 - val_mean_squared_error: 0.5863
# Epoch 6/130
# 37/37 [==============================] - 4s 113ms/step - loss: 1.0328 - mean_squared_error: 1.0328 - val_loss: 0.6684 - val_mean_squared_error: 0.6684
# Epoch 7/130
# 37/37 [==============================] - 4s 113ms/step - loss: 1.0278 - mean_squared_error: 1.0278 - val_loss: 0.5765 - val_mean_squared_error: 0.5765
# Epoch 8/130
# 37/37 [==============================] - 4s 114ms/step - loss: 1.0069 - mean_squared_error: 1.0069 - val_loss: 0.7730 - val_mean_squared_error: 0.7730
# Epoch 9/130
# 37/37 [==============================] - 4s 118ms/step - loss: 1.0022 - mean_squared_error: 1.0022 - val_loss: 0.6224 - val_mean_squared_error: 0.6224
# Epoch 10/130
# 37/37 [==============================] - 5s 136ms/step - loss: 1.0052 - mean_squared_error: 1.0052 - val_loss: 0.7078 - val_mean_squared_error: 0.7078
# Epoch 11/130
# 37/37 [==============================] - 5s 142ms/step - loss: 1.0040 - mean_squared_error: 1.0040 - val_loss: 0.6267 - val_mean_squared_error: 0.6267
# Epoch 12/130
# 37/37 [==============================] - 5s 148ms/step - loss: 1.0127 - mean_squared_error: 1.0127 - val_loss: 0.5723 - val_mean_squared_error: 0.5723
# Epoch 13/130
# 37/37 [==============================] - 5s 144ms/step - loss: 1.0113 - mean_squared_error: 1.0113 - val_loss: 0.5910 - val_mean_squared_error: 0.5910
# Epoch 14/130
# 37/37 [==============================] - 5s 133ms/step - loss: 0.9980 - mean_squared_error: 0.9980 - val_loss: 0.5991 - val_mean_squared_error: 0.5991
# Epoch 15/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9817 - mean_squared_error: 0.9817 - val_loss: 0.5964 - val_mean_squared_error: 0.5964
# Epoch 16/130
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9827 - mean_squared_error: 0.9827 - val_loss: 0.5999 - val_mean_squared_error: 0.5999
# Epoch 17/130
# 37/37 [==============================] - 5s 132ms/step - loss: 0.9846 - mean_squared_error: 0.9846 - val_loss: 0.6503 - val_mean_squared_error: 0.6503
# Epoch 18/130
# 37/37 [==============================] - 5s 135ms/step - loss: 0.9880 - mean_squared_error: 0.9880 - val_loss: 0.6188 - val_mean_squared_error: 0.6188
# Epoch 19/130
# 37/37 [==============================] - 5s 145ms/step - loss: 1.0037 - mean_squared_error: 1.0037 - val_loss: 0.5844 - val_mean_squared_error: 0.5844
# Epoch 20/130
# 37/37 [==============================] - 5s 132ms/step - loss: 0.9805 - mean_squared_error: 0.9805 - val_loss: 0.6532 - val_mean_squared_error: 0.6532
# Epoch 21/130
# 37/37 [==============================] - 4s 121ms/step - loss: 0.9829 - mean_squared_error: 0.9829 - val_loss: 0.6033 - val_mean_squared_error: 0.6033
# Epoch 22/130
# 37/37 [==============================] - 5s 132ms/step - loss: 0.9704 - mean_squared_error: 0.9704 - val_loss: 0.6007 - val_mean_squared_error: 0.6007
# Epoch 23/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.9841 - mean_squared_error: 0.9841 - val_loss: 0.5863 - val_mean_squared_error: 0.5863
# Epoch 24/130
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9793 - mean_squared_error: 0.9793 - val_loss: 0.6312 - val_mean_squared_error: 0.6312
# Epoch 25/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.9822 - mean_squared_error: 0.9822 - val_loss: 0.5810 - val_mean_squared_error: 0.5810
# Epoch 26/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.9752 - mean_squared_error: 0.9752 - val_loss: 0.6014 - val_mean_squared_error: 0.6014
# Epoch 27/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9810 - mean_squared_error: 0.9810 - val_loss: 0.5728 - val_mean_squared_error: 0.5728
# Epoch 28/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.9753 - mean_squared_error: 0.9753 - val_loss: 0.6123 - val_mean_squared_error: 0.6123
# Epoch 29/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.9556 - mean_squared_error: 0.9556 - val_loss: 0.5830 - val_mean_squared_error: 0.5830
# Epoch 30/130
# 37/37 [==============================] - 4s 121ms/step - loss: 0.9651 - mean_squared_error: 0.9651 - val_loss: 0.6278 - val_mean_squared_error: 0.6278
# Epoch 31/130
# 37/37 [==============================] - 5s 133ms/step - loss: 0.9593 - mean_squared_error: 0.9593 - val_loss: 0.6097 - val_mean_squared_error: 0.6097
# Epoch 32/130
# 37/37 [==============================] - 5s 131ms/step - loss: 0.9581 - mean_squared_error: 0.9581 - val_loss: 0.5971 - val_mean_squared_error: 0.5971
# Epoch 33/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.9583 - mean_squared_error: 0.9583 - val_loss: 0.6256 - val_mean_squared_error: 0.6256
# Epoch 34/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.9505 - mean_squared_error: 0.9505 - val_loss: 0.7071 - val_mean_squared_error: 0.7071
# Epoch 35/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.9603 - mean_squared_error: 0.9603 - val_loss: 0.5850 - val_mean_squared_error: 0.5850
# Epoch 36/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.9535 - mean_squared_error: 0.9535 - val_loss: 0.6480 - val_mean_squared_error: 0.6480
# Epoch 37/130
# 37/37 [==============================] - 4s 121ms/step - loss: 0.9387 - mean_squared_error: 0.9387 - val_loss: 0.6423 - val_mean_squared_error: 0.6423
# Epoch 38/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.9336 - mean_squared_error: 0.9336 - val_loss: 0.6173 - val_mean_squared_error: 0.6173
# Epoch 39/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.9502 - mean_squared_error: 0.9502 - val_loss: 0.6334 - val_mean_squared_error: 0.6334
# Epoch 40/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9495 - mean_squared_error: 0.9495 - val_loss: 0.6015 - val_mean_squared_error: 0.6015
# Epoch 41/130
# 37/37 [==============================] - 6s 151ms/step - loss: 0.9307 - mean_squared_error: 0.9307 - val_loss: 0.5985 - val_mean_squared_error: 0.5985
# Epoch 42/130
# 37/37 [==============================] - 5s 127ms/step - loss: 0.9341 - mean_squared_error: 0.9341 - val_loss: 0.6103 - val_mean_squared_error: 0.6103
# Epoch 43/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.9246 - mean_squared_error: 0.9246 - val_loss: 0.6272 - val_mean_squared_error: 0.6272
# Epoch 44/130
# 37/37 [==============================] - 5s 144ms/step - loss: 0.9432 - mean_squared_error: 0.9432 - val_loss: 0.6479 - val_mean_squared_error: 0.6479
# Epoch 45/130
# 37/37 [==============================] - 6s 153ms/step - loss: 0.9337 - mean_squared_error: 0.9337 - val_loss: 0.6077 - val_mean_squared_error: 0.6077
# Epoch 46/130
# 37/37 [==============================] - 5s 142ms/step - loss: 0.9250 - mean_squared_error: 0.9250 - val_loss: 0.6086 - val_mean_squared_error: 0.6086
# Epoch 47/130
# 37/37 [==============================] - 5s 142ms/step - loss: 0.9217 - mean_squared_error: 0.9217 - val_loss: 0.5991 - val_mean_squared_error: 0.5991
# Epoch 48/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.9248 - mean_squared_error: 0.9248 - val_loss: 0.6003 - val_mean_squared_error: 0.6003
# Epoch 49/130
# 37/37 [==============================] - 5s 129ms/step - loss: 0.9187 - mean_squared_error: 0.9187 - val_loss: 0.6662 - val_mean_squared_error: 0.6662
# Epoch 50/130
# 37/37 [==============================] - 5s 130ms/step - loss: 0.9259 - mean_squared_error: 0.9259 - val_loss: 0.5932 - val_mean_squared_error: 0.5932
# Epoch 51/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.9015 - mean_squared_error: 0.9015 - val_loss: 0.6358 - val_mean_squared_error: 0.6358
# Epoch 52/130
# 37/37 [==============================] - 4s 120ms/step - loss: 0.8813 - mean_squared_error: 0.8813 - val_loss: 0.6369 - val_mean_squared_error: 0.6369
# Epoch 53/130
# 37/37 [==============================] - 4s 117ms/step - loss: 0.8988 - mean_squared_error: 0.8988 - val_loss: 0.6111 - val_mean_squared_error: 0.6111
# Epoch 54/130
# 37/37 [==============================] - 4s 118ms/step - loss: 0.8784 - mean_squared_error: 0.8784 - val_loss: 0.6402 - val_mean_squared_error: 0.6402
# Epoch 55/130
# 37/37 [==============================] - 4s 119ms/step - loss: 0.8989 - mean_squared_error: 0.8989 - val_loss: 0.5980 - val_mean_squared_error: 0.5980
# Epoch 56/130
# 37/37 [==============================] - 4s 120ms/step - loss: 0.9338 - mean_squared_error: 0.9338 - val_loss: 0.6151 - val_mean_squared_error: 0.6151
# Epoch 57/130
# 37/37 [==============================] - 4s 121ms/step - loss: 0.8778 - mean_squared_error: 0.8778 - val_loss: 0.6163 - val_mean_squared_error: 0.6163
# Epoch 58/130
# 37/37 [==============================] - 4s 119ms/step - loss: 0.8920 - mean_squared_error: 0.8920 - val_loss: 0.6002 - val_mean_squared_error: 0.6002
# Epoch 59/130
# 37/37 [==============================] - 4s 120ms/step - loss: 0.8492 - mean_squared_error: 0.8492 - val_loss: 0.6610 - val_mean_squared_error: 0.6610
# Epoch 60/130
# 37/37 [==============================] - 4s 119ms/step - loss: 0.8606 - mean_squared_error: 0.8606 - val_loss: 0.6302 - val_mean_squared_error: 0.6302
# Epoch 61/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.8638 - mean_squared_error: 0.8638 - val_loss: 0.6161 - val_mean_squared_error: 0.6161
# Epoch 62/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.8520 - mean_squared_error: 0.8520 - val_loss: 0.6875 - val_mean_squared_error: 0.6875
# Epoch 63/130
# 37/37 [==============================] - 4s 120ms/step - loss: 0.8433 - mean_squared_error: 0.8433 - val_loss: 0.6460 - val_mean_squared_error: 0.6460
# Epoch 64/130
# 37/37 [==============================] - 5s 138ms/step - loss: 0.8684 - mean_squared_error: 0.8684 - val_loss: 0.5928 - val_mean_squared_error: 0.5928
# Epoch 65/130
# 37/37 [==============================] - 7s 181ms/step - loss: 0.8008 - mean_squared_error: 0.8008 - val_loss: 0.6746 - val_mean_squared_error: 0.6746
# Epoch 66/130
# 37/37 [==============================] - 5s 149ms/step - loss: 0.8294 - mean_squared_error: 0.8294 - val_loss: 0.6395 - val_mean_squared_error: 0.6395
# Epoch 67/130
# 37/37 [==============================] - 5s 134ms/step - loss: 0.7972 - mean_squared_error: 0.7972 - val_loss: 0.6937 - val_mean_squared_error: 0.6937
# Epoch 68/130
# 37/37 [==============================] - 5s 136ms/step - loss: 0.8149 - mean_squared_error: 0.8149 - val_loss: 0.6153 - val_mean_squared_error: 0.6153
# Epoch 69/130
# 37/37 [==============================] - 5s 135ms/step - loss: 0.8003 - mean_squared_error: 0.8003 - val_loss: 0.6240 - val_mean_squared_error: 0.6240
# Epoch 70/130
# 37/37 [==============================] - 5s 124ms/step - loss: 0.8336 - mean_squared_error: 0.8336 - val_loss: 0.6032 - val_mean_squared_error: 0.6032
# Epoch 71/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.7868 - mean_squared_error: 0.7868 - val_loss: 0.6474 - val_mean_squared_error: 0.6474
# Epoch 72/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.7637 - mean_squared_error: 0.7637 - val_loss: 0.6960 - val_mean_squared_error: 0.6960
# Epoch 73/130
# 37/37 [==============================] - 4s 121ms/step - loss: 0.7709 - mean_squared_error: 0.7709 - val_loss: 0.6798 - val_mean_squared_error: 0.6798
# Epoch 74/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.7444 - mean_squared_error: 0.7444 - val_loss: 0.6855 - val_mean_squared_error: 0.6855
# Epoch 75/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.7391 - mean_squared_error: 0.7391 - val_loss: 0.6656 - val_mean_squared_error: 0.6656
# Epoch 76/130
# 37/37 [==============================] - 6s 151ms/step - loss: 0.8022 - mean_squared_error: 0.8022 - val_loss: 0.7762 - val_mean_squared_error: 0.7762
# Epoch 77/130
# 37/37 [==============================] - 8s 213ms/step - loss: 0.7573 - mean_squared_error: 0.7573 - val_loss: 0.7065 - val_mean_squared_error: 0.7065
# Epoch 78/130
# 37/37 [==============================] - 8s 220ms/step - loss: 0.7019 - mean_squared_error: 0.7019 - val_loss: 0.8154 - val_mean_squared_error: 0.8154
# Epoch 79/130
# 37/37 [==============================] - 8s 214ms/step - loss: 0.7062 - mean_squared_error: 0.7062 - val_loss: 0.7562 - val_mean_squared_error: 0.7562
# Epoch 80/130
# 37/37 [==============================] - 8s 218ms/step - loss: 0.6822 - mean_squared_error: 0.6822 - val_loss: 0.7993 - val_mean_squared_error: 0.7993
# Epoch 81/130
# 37/37 [==============================] - 8s 230ms/step - loss: 0.6830 - mean_squared_error: 0.6830 - val_loss: 0.6480 - val_mean_squared_error: 0.6480
# Epoch 82/130
# 37/37 [==============================] - 8s 220ms/step - loss: 0.6997 - mean_squared_error: 0.6997 - val_loss: 0.7099 - val_mean_squared_error: 0.7099
# Epoch 83/130
# 37/37 [==============================] - 6s 155ms/step - loss: 0.6631 - mean_squared_error: 0.6631 - val_loss: 0.9044 - val_mean_squared_error: 0.9044
# Epoch 84/130
# 37/37 [==============================] - 5s 145ms/step - loss: 0.6745 - mean_squared_error: 0.6745 - val_loss: 0.7109 - val_mean_squared_error: 0.7109
# Epoch 85/130
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6806 - mean_squared_error: 0.6806 - val_loss: 0.7158 - val_mean_squared_error: 0.7158
# Epoch 86/130
# 37/37 [==============================] - 5s 137ms/step - loss: 0.6448 - mean_squared_error: 0.6448 - val_loss: 0.7235 - val_mean_squared_error: 0.7235
# Epoch 87/130
# 37/37 [==============================] - 5s 135ms/step - loss: 0.6528 - mean_squared_error: 0.6528 - val_loss: 0.7636 - val_mean_squared_error: 0.7636
# Epoch 88/130
# 37/37 [==============================] - 5s 137ms/step - loss: 0.6419 - mean_squared_error: 0.6419 - val_loss: 0.8777 - val_mean_squared_error: 0.8777
# Epoch 89/130
# 37/37 [==============================] - 5s 127ms/step - loss: 0.6776 - mean_squared_error: 0.6776 - val_loss: 0.9345 - val_mean_squared_error: 0.9345
# Epoch 90/130
# 37/37 [==============================] - 5s 124ms/step - loss: 0.6317 - mean_squared_error: 0.6317 - val_loss: 0.7966 - val_mean_squared_error: 0.7966
# Epoch 91/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.5887 - mean_squared_error: 0.5887 - val_loss: 0.8586 - val_mean_squared_error: 0.8586
# Epoch 92/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.6361 - mean_squared_error: 0.6361 - val_loss: 0.7782 - val_mean_squared_error: 0.7782
# Epoch 93/130
# 37/37 [==============================] - 4s 122ms/step - loss: 0.6000 - mean_squared_error: 0.6000 - val_loss: 0.7524 - val_mean_squared_error: 0.7524
# Epoch 94/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.6063 - mean_squared_error: 0.6063 - val_loss: 0.7597 - val_mean_squared_error: 0.7597
# Epoch 95/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.5905 - mean_squared_error: 0.5905 - val_loss: 0.7211 - val_mean_squared_error: 0.7211
# Epoch 96/130
# 37/37 [==============================] - 4s 118ms/step - loss: 0.5243 - mean_squared_error: 0.5243 - val_loss: 0.7662 - val_mean_squared_error: 0.7662
# Epoch 97/130
# 37/37 [==============================] - 4s 119ms/step - loss: 0.5408 - mean_squared_error: 0.5408 - val_loss: 0.7920 - val_mean_squared_error: 0.7920
# Epoch 98/130
# 37/37 [==============================] - 4s 118ms/step - loss: 0.5305 - mean_squared_error: 0.5305 - val_loss: 0.9668 - val_mean_squared_error: 0.9668
# Epoch 99/130
# 37/37 [==============================] - 4s 118ms/step - loss: 0.5183 - mean_squared_error: 0.5183 - val_loss: 0.8694 - val_mean_squared_error: 0.8694
# Epoch 100/130
# 37/37 [==============================] - 4s 120ms/step - loss: 0.5323 - mean_squared_error: 0.5323 - val_loss: 0.7651 - val_mean_squared_error: 0.7651
# Epoch 101/130
# 37/37 [==============================] - 5s 149ms/step - loss: 0.5411 - mean_squared_error: 0.5411 - val_loss: 0.8458 - val_mean_squared_error: 0.8458
# Epoch 102/130
# 37/37 [==============================] - 6s 156ms/step - loss: 0.5153 - mean_squared_error: 0.5153 - val_loss: 0.8704 - val_mean_squared_error: 0.8704
# Epoch 103/130
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4771 - mean_squared_error: 0.4771 - val_loss: 0.8101 - val_mean_squared_error: 0.8101
# Epoch 104/130
# 37/37 [==============================] - 5s 145ms/step - loss: 0.4459 - mean_squared_error: 0.4459 - val_loss: 0.8476 - val_mean_squared_error: 0.8476
# Epoch 105/130
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4783 - mean_squared_error: 0.4783 - val_loss: 0.8965 - val_mean_squared_error: 0.8965
# Epoch 106/130
# 37/37 [==============================] - 5s 131ms/step - loss: 0.4717 - mean_squared_error: 0.4717 - val_loss: 0.7509 - val_mean_squared_error: 0.7509
# Epoch 107/130
# 37/37 [==============================] - 4s 119ms/step - loss: 0.4833 - mean_squared_error: 0.4833 - val_loss: 0.8903 - val_mean_squared_error: 0.8903
# Epoch 108/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.4835 - mean_squared_error: 0.4835 - val_loss: 0.8522 - val_mean_squared_error: 0.8522
# Epoch 109/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.4243 - mean_squared_error: 0.4243 - val_loss: 0.8126 - val_mean_squared_error: 0.8126
# Epoch 110/130
# 37/37 [==============================] - 4s 117ms/step - loss: 0.4708 - mean_squared_error: 0.4708 - val_loss: 0.9425 - val_mean_squared_error: 0.9425
# Epoch 111/130
# 37/37 [==============================] - 5s 129ms/step - loss: 0.4245 - mean_squared_error: 0.4245 - val_loss: 0.9295 - val_mean_squared_error: 0.9295
# Epoch 112/130
# 37/37 [==============================] - 5s 133ms/step - loss: 0.4687 - mean_squared_error: 0.4687 - val_loss: 0.7708 - val_mean_squared_error: 0.7708
# Epoch 113/130
# 37/37 [==============================] - 5s 137ms/step - loss: 0.3953 - mean_squared_error: 0.3953 - val_loss: 1.0638 - val_mean_squared_error: 1.0638
# Epoch 114/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.3806 - mean_squared_error: 0.3806 - val_loss: 0.8479 - val_mean_squared_error: 0.8479
# Epoch 115/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.3823 - mean_squared_error: 0.3823 - val_loss: 0.8707 - val_mean_squared_error: 0.8707
# Epoch 116/130
# 37/37 [==============================] - 5s 122ms/step - loss: 0.3640 - mean_squared_error: 0.3640 - val_loss: 0.9058 - val_mean_squared_error: 0.9058
# Epoch 117/130
# 37/37 [==============================] - 5s 124ms/step - loss: 0.3934 - mean_squared_error: 0.3934 - val_loss: 0.8018 - val_mean_squared_error: 0.8018
# Epoch 118/130
# 37/37 [==============================] - 5s 127ms/step - loss: 0.3768 - mean_squared_error: 0.3768 - val_loss: 0.9439 - val_mean_squared_error: 0.9439
# Epoch 119/130
# 37/37 [==============================] - 5s 148ms/step - loss: 0.3622 - mean_squared_error: 0.3622 - val_loss: 0.9044 - val_mean_squared_error: 0.9044
# Epoch 120/130
# 37/37 [==============================] - 5s 144ms/step - loss: 0.3772 - mean_squared_error: 0.3772 - val_loss: 0.9619 - val_mean_squared_error: 0.9619
# Epoch 121/130
# 37/37 [==============================] - 5s 124ms/step - loss: 0.3544 - mean_squared_error: 0.3544 - val_loss: 0.8317 - val_mean_squared_error: 0.8317
# Epoch 122/130
# 37/37 [==============================] - 5s 123ms/step - loss: 0.3987 - mean_squared_error: 0.3987 - val_loss: 0.9363 - val_mean_squared_error: 0.9363
# Epoch 123/130
# 37/37 [==============================] - 5s 126ms/step - loss: 0.3790 - mean_squared_error: 0.3790 - val_loss: 0.9573 - val_mean_squared_error: 0.9573
# Epoch 124/130
# 37/37 [==============================] - 5s 125ms/step - loss: 0.3372 - mean_squared_error: 0.3372 - val_loss: 0.8755 - val_mean_squared_error: 0.8755
# Epoch 125/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.3463 - mean_squared_error: 0.3463 - val_loss: 0.9763 - val_mean_squared_error: 0.9763
# Epoch 126/130
# 37/37 [==============================] - 5s 130ms/step - loss: 0.3508 - mean_squared_error: 0.3508 - val_loss: 0.8340 - val_mean_squared_error: 0.8340
# Epoch 127/130
# 37/37 [==============================] - 5s 131ms/step - loss: 0.3329 - mean_squared_error: 0.3329 - val_loss: 1.0926 - val_mean_squared_error: 1.0926
# Epoch 128/130
# 37/37 [==============================] - 5s 128ms/step - loss: 0.3696 - mean_squared_error: 0.3696 - val_loss: 0.8462 - val_mean_squared_error: 0.8462
# Epoch 129/130
# 37/37 [==============================] - 5s 131ms/step - loss: 0.3425 - mean_squared_error: 0.3425 - val_loss: 0.8704 - val_mean_squared_error: 0.8704
# Epoch 130/130
# 37/37 [==============================] - 5s 127ms/step - loss: 0.3371 - mean_squared_error: 0.3371 - val_loss: 0.9242 - val_mean_squared_error: 0.9242

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_test)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 6s 32ms/step

# %%
predictions.shape
# Out:
# (361, 1)

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled = model.predict(X_train)

# Inverse transform predictions and actual values to original scale
predictions = scaler.inverse_transform(predictions_scaled)
actual = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 46/46 [==============================] - 2s 32ms/step

# %%
import matplotlib.pyplot as plt

# Predict values for testing data
predictions_scaled_test = model.predict(X_test)

# Inverse transform predictions and actual values to original scale for testing data
predictions_test = scaler.inverse_transform(predictions_scaled_test)
actual_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# Predict values for training data
predictions_scaled_train = model.predict(X_train)

# Inverse transform predictions and actual values to original scale for training data
predictions_train = scaler.inverse_transform(predictions_scaled_train)
actual_train = scaler.inverse_transform(y_train.reshape(-1, 1))

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(actual_train, label='Actual (Train)', color='blue')
plt.plot(predictions_train, label='Predicted (Train)', color='orange')
plt.plot(len(predictions_train) + np.arange(len(predictions_test)), predictions_test, label='Predicted (Test)', color='red')
plt.xlabel('Time')
plt.ylabel('HCHO reading')
plt.title('Actual vs Predicted HCHO reading')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 31ms/step
# 46/46 [==============================] - 2s 32ms/step

# %%
y_test = actual
predicted_values = predictions.reshape(-1, 1)
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): 0.6127082763821532
# Mean Absolute Error (MAE): 1.98389300422124e-05
# Mean Squared Error (MSE): 1.0995352192906497e-09
# Root Mean Squared Error (RMSE): 3.315924033042147e-05
# Median Absolute Error: 1.1186292036115726e-05
# Explained Variance Score: 0.6145091007486354

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare your data
data = pd.read_csv("../NullValueHandled/NuwaraEliyaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data.rename(columns={'Current Date': 'ds', 'HCHO reading': 'y'}, inplace=True)
data['ds'] = pd.to_datetime(data['ds'])

# Define holidays
holidays = pd.DataFrame({
    'holiday': 'covid',
    'ds': pd.to_datetime(['2020-03-15', '2021-12-31']), 
    'lower_window': 0,
    'upper_window': 1,
})

train_size = int(0.9 * len(data)) 
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Initialize and fit the Prophet model with holidays
model = Prophet(holidays=holidays) 
model.fit(train_data)

# Create a dataframe for future dates predictions
future = model.make_future_dataframe(periods=730)

# Make predictions
forecast = model.predict(future)

# Plot the forecast
fig1 = model.plot(forecast)
ax = fig1.gca()

# Overlay actual data
ax.plot(train_data['ds'], train_data['y'], 'k.', label='Actual Data')

plt.show()
# Out:
# 19:15:26 - cmdstanpy - INFO - Chain [1] start processing
# 19:15:26 - cmdstanpy - INFO - Chain [1] done processing

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 8))

# Plot actual data
sns.lineplot(data=train_data, x='ds', y='y', label='Actual Data', color='black', marker='o', linestyle='None')

# Plot yhat - forecast
sns.lineplot(data=forecast, x='ds', y='yhat', label='Forecast (yhat)', color='#6a0dad')  # Purple

# Plot yhat_upper
sns.lineplot(data=forecast, x='ds', y='yhat_upper', label='Forecast Upper Bound (yhat_upper)', color='#33a1ff')  # Teal

# Plot yhat_lower
sns.lineplot(data=forecast, x='ds', y='yhat_lower', label='Forecast Lower Bound (yhat_lower)', color='#00e6e6')  # Light Teal

plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='#d9b3ff', alpha=0.2, label='Confidence Interval')  # Light Purple

plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('HCHO Reading Forecast')

# Adjust legend
plt.legend()

plt.show()

# %%
# Plot the forecast components
fig2 = model.plot_components(forecast)

# %%
from tabulate import tabulate

y_test = test_data['y']
predicted_values = forecast.loc[forecast['ds'].isin(test_data['ds']), 'yhat']  # Extract forecasted values for test period
r2 = r2_score(y_test, predicted_values)
mae = mean_absolute_error(y_test, predicted_values)
mse = mean_squared_error(y_test, predicted_values)
rmse = mean_squared_error(y_test, predicted_values, squared=False)
median_absolute = median_absolute_error(y_test, predicted_values)
explained_variance = explained_variance_score(y_test, predicted_values)

# Print evaluation metrics
print(f"R-squared (Coefficient of Determination): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Median Absolute Error: {median_absolute}")
print(f"Explained Variance Score: {explained_variance}")
# Out:
# R-squared (Coefficient of Determination): -0.03332473696988747
# Mean Absolute Error (MAE): 4.640746178003005e-05
# Mean Squared Error (MSE): 4.394006741650661e-09
# Root Mean Squared Error (RMSE): 6.628730452847408e-05
# Median Absolute Error: 2.999635321502574e-05
# Explained Variance Score: -0.013782492770155974

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare your data
data = pd.read_csv("../NullValueHandled/BibileMonaragalaHandledNullValues.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)
data.rename(columns={'Current Date': 'ds', 'HCHO reading': 'y'}, inplace=True)
data['ds'] = pd.to_datetime(data['ds'])

# Define holidays
holidays = pd.DataFrame({
    'holiday': 'covid',
    'ds': pd.to_datetime(['2020-03-15', '2021-12-31']), 
    'lower_window': 0,
    'upper_window': 1,
})

train_size = int(0.90 * len(data)) 
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Initialize and fit the Prophet model with holidays
model = Prophet(holidays=holidays,) 
model.fit(train_data)

# Create a dataframe for future dates predictions
future = model.make_future_dataframe(periods=365)

# Make predictions
forecast = model.predict(future)

# Plot the forecast
fig1 = model.plot(forecast)
ax = fig1.gca()

# Overlay actual data
ax.plot(train_data['ds'], train_data['y'], 'k.', label='Actual Data')

plt.show()

# %% [markdown]
# #### Nuwara Eliya Multi Variate Model

# %%
data = pd.read_csv("../AnalysedFinalData/nuwaraEliyaData.csv", parse_dates=True)
data.drop(columns=["Next Date"], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Current Date          1826 non-null   object
#  1   HCHO reading          1826 non-null   float64
#  2   Region                1826 non-null   object
#  3   LATITUDE              1826 non-null   float64
#  4   LONGITUDE             1826 non-null   float64
#  5   ELEVATION             1826 non-null   float64
#  6   PRCP                  1826 non-null   float64
#  7   TAVG                  1826 non-null   float64
#  8   TMAX                  1826 non-null   float64
#  9   TMIN                  1826 non-null   float64
#  10  Population            1826 non-null   int64
#  11  Area_sq_km            1826 non-null   int64
#  12  population_density    1826 non-null   float64
#  13  Proximity(km)         1826 non-null   int64
#  14  carbon_monoxide       1826 non-null   float64
#  15  nitogen_dioxide       1826 non-null   float64
#  16  ozone                 1826 non-null   float64
#  17  new_covid_patients    1826 non-null   int64
#  18  total_covid_patients  1826 non-null   int64
#  19  lockdown_status       1826 non-null   object
#  20  covid_range_status    1826 non-null   object
# dtypes: float64(12), int64(5), object(4)
# memory usage: 299.7+ KB

# %%
data.head()
# Out:
#   Current Date  HCHO reading               Region  LATITUDE  LONGITUDE  \
# 0   2019-01-01      0.000191  Nuwara Eliya Proper     6.967     80.767
# 1   2019-01-02      0.000191  Nuwara Eliya Proper     6.967     80.767
# 2   2019-01-03      0.000191  Nuwara Eliya Proper     6.967     80.767
# 3   2019-01-04      0.000051  Nuwara Eliya Proper     6.967     80.767
# 4   2019-01-05      0.000065  Nuwara Eliya Proper     6.967     80.767
#
#    ELEVATION  PRCP  TAVG  TMAX  TMIN  Population  Area_sq_km  \
# 0     1880.0   0.0  61.0  71.0  49.0      768000        1741
# 1     1880.0   0.0  59.0  71.0  49.0      768000        1741
# 2     1880.0   0.0  59.0  71.0  49.0      768000        1741
# 3     1880.0   0.0  59.0  72.0  47.0      768000        1741
# 4     1880.0   0.0  55.0  68.0  48.0      768000        1741
#
#    population_density  Proximity(km)  carbon_monoxide  nitogen_dioxide  \
# 0              441.13            101         0.031612         0.000012
# 1              441.13            101         0.031380         0.000015
# 2              441.13            101         0.030029         0.000017
# 3              441.13            101         0.032376         0.000015
# 4              441.13            101         0.031173         0.000016
#
#       ozone  new_covid_patients  total_covid_patients lockdown_status  \
# 0  0.115633                   0                     0          Before
# 1  0.115633                   0                     0          Before
# 2  0.115633                   0                     0          Before
# 3  0.115633                   0                     0          Before
# 4  0.115633                   0                     0          Before
#
#   covid_range_status
# 0             Before
# 1             Before
# 2             Before
# 3             Before
# 4             Before

# %% [markdown]
# #### remove constant data

# %%
data.columns
# Out:
# Index(['Current Date', 'HCHO reading', 'Region', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 'Area_sq_km',
#        'population_density', 'Proximity(km)', 'carbon_monoxide',
#        'nitogen_dioxide', 'ozone', 'new_covid_patients',
#        'total_covid_patients', 'lockdown_status', 'covid_range_status'],
#       dtype='object')

# %%
data.drop(columns=['Region', 'LATITUDE', 'LONGITUDE',
       'ELEVATION','Area_sq_km', 'Proximity(km)'], inplace=True)

# %%
data.head()
# Out:
#   Current Date  HCHO reading  PRCP  TAVG  TMAX  TMIN  Population  \
# 0   2019-01-01      0.000191   0.0  61.0  71.0  49.0      768000
# 1   2019-01-02      0.000191   0.0  59.0  71.0  49.0      768000
# 2   2019-01-03      0.000191   0.0  59.0  71.0  49.0      768000
# 3   2019-01-04      0.000051   0.0  59.0  72.0  47.0      768000
# 4   2019-01-05      0.000065   0.0  55.0  68.0  48.0      768000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              441.13         0.031612         0.000012  0.115633
# 1              441.13         0.031380         0.000015  0.115633
# 2              441.13         0.030029         0.000017  0.115633
# 3              441.13         0.032376         0.000015  0.115633
# 4              441.13         0.031173         0.000016  0.115633
#
#    new_covid_patients  total_covid_patients lockdown_status covid_range_status
# 0                   0                     0          Before             Before
# 1                   0                     0          Before             Before
# 2                   0                     0          Before             Before
# 3                   0                     0          Before             Before
# 4                   0                     0          Before             Before

# %% [markdown]
# #### Encode Categorical data

# %%
from sklearn.preprocessing import LabelEncoder
 
dates = data["Current Date"]

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate through each column in the DataFrame
for column in data.columns:
    # Check if the column is of categorical type
    if data[column].dtype == 'object':
        # Fit label encoder and transform values
        data[column] = label_encoder.fit_transform(data[column])

# %%
data["Current Date"] = dates
data.head()
# Out:
#   Current Date  HCHO reading  PRCP  TAVG  TMAX  TMIN  Population  \
# 0   2019-01-01      0.000191   0.0  61.0  71.0  49.0      768000
# 1   2019-01-02      0.000191   0.0  59.0  71.0  49.0      768000
# 2   2019-01-03      0.000191   0.0  59.0  71.0  49.0      768000
# 3   2019-01-04      0.000051   0.0  59.0  72.0  47.0      768000
# 4   2019-01-05      0.000065   0.0  55.0  68.0  48.0      768000
#
#    population_density  carbon_monoxide  nitogen_dioxide     ozone  \
# 0              441.13         0.031612         0.000012  0.115633
# 1              441.13         0.031380         0.000015  0.115633
# 2              441.13         0.030029         0.000017  0.115633
# 3              441.13         0.032376         0.000015  0.115633
# 4              441.13         0.031173         0.000016  0.115633
#
#    new_covid_patients  total_covid_patients  lockdown_status  \
# 0                   0                     0                1
# 1                   0                     0                1
# 2                   0                     0                1
# 3                   0                     0                1
# 4                   0                     0                1
#
#    covid_range_status
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# #### Check correlations

# %%
data.corr(numeric_only=True)["HCHO reading"]
# Out:
# HCHO reading            1.000000
# PRCP                   -0.025234
# TAVG                    0.029537
# TMAX                    0.153014
# TMIN                   -0.139301
# Population             -0.033461
# population_density     -0.033470
# carbon_monoxide         0.142956
# nitogen_dioxide         0.099964
# ozone                  -0.030131
# new_covid_patients     -0.069096
# total_covid_patients   -0.055533
# lockdown_status        -0.034339
# covid_range_status     -0.019078
# Name: HCHO reading, dtype: float64

# %%
data.shape
# Out:
# (1826, 15)

# %% [markdown]
# #### remove covid range status

# %%
data.drop(columns=["covid_range_status"], inplace=True)

# %% [markdown]
# #### Devide X and Y

# %%
X = data.drop(columns=["HCHO reading"])
y = data["HCHO reading"]

# %%
X.head()
# Out:
#   Current Date  PRCP  TAVG  TMAX  TMIN  Population  population_density  \
# 0   2019-01-01   0.0  61.0  71.0  49.0      768000              441.13
# 1   2019-01-02   0.0  59.0  71.0  49.0      768000              441.13
# 2   2019-01-03   0.0  59.0  71.0  49.0      768000              441.13
# 3   2019-01-04   0.0  59.0  72.0  47.0      768000              441.13
# 4   2019-01-05   0.0  55.0  68.0  48.0      768000              441.13
#
#    carbon_monoxide  nitogen_dioxide     ozone  new_covid_patients  \
# 0         0.031612         0.000012  0.115633                   0
# 1         0.031380         0.000015  0.115633                   0
# 2         0.030029         0.000017  0.115633                   0
# 3         0.032376         0.000015  0.115633                   0
# 4         0.031173         0.000016  0.115633                   0
#
#    total_covid_patients  lockdown_status
# 0                     0                1
# 1                     0                1
# 2                     0                1
# 3                     0                1
# 4                     0                1

# %% [markdown]
# #### Select features based on Correlations

# %%
data.corr(numeric_only=True)["HCHO reading"]
# Out:
# HCHO reading            1.000000
# PRCP                   -0.025234
# TAVG                    0.029537
# TMAX                    0.153014
# TMIN                   -0.139301
# Population             -0.033461
# population_density     -0.033470
# carbon_monoxide         0.142956
# nitogen_dioxide         0.099964
# ozone                  -0.030131
# new_covid_patients     -0.069096
# total_covid_patients   -0.055533
# lockdown_status        -0.034339
# Name: HCHO reading, dtype: float64
